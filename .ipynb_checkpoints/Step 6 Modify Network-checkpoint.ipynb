# %%
using Pkg
Pkg.activate(".")

# %%
using JuMP
using DataFrames
using CSV
using Gurobi
using DataFrames

# %%
include("./parameters.jl")
include("./get_functions.jl")

loadcsv = CSV.File("./LOAD.csv");

# %%
include("./modification_functions.jl")
# Out:
# construct_ef_model (generic function with 1 method)

# %%
loaddis = load_distribution_dict(loadcsv);

# %%
ptdfdict = ptdf_dict(ptdfdf);

# %%
# Below are test cases. Construction for getting and modifying uncertainty vectors (i.e. load and wind)
#     will be done elsewhere.
#=
loadraw1 = [985.0197922,
985.7248887,
1001.58956,
1036.139287,
1139.788471,
1286.801089,
1347.086838,
1305.486145,
1232.508659,
1184.20955,
1153.185304,
1129.212024,
1107.706581,
1093.957199,
1087.611331,
1091.489362,
1170.460168,
1280.102672,
1266.000742,
1245.200396,
1204.657348,
1117.577932,
1031.203612,
991.0131123];

loadraw2 = [970.9178624,
968.4500247,
977.9688273,
1011.46091,
1097.83523,
1221.227115,
1274.109352,
1224.752598,
1174.690747,
1150.364918,
1128.506927,
1120.750866,
1112.642256,
1101.713261,
1099.245423,
1101.360713,
1163.056655,
1265.295646,
1256.129391,
1222.989857,
1176.10094,
1094.662296,
1009.345621,
963.8668976]

windraw1 = [713.2,
712.8,
708.4,
710.7,
701.4,
682.5,
614.7,
517.7,
426.6,
274.2,
93,
6.3,
3.8,
1.1,
0,
0,
0.9,
276.3,
272.9,
345.6,
411.7,
376.6,
561.3,
568.4];

windraw2 = [630,
672.3,
661.3,
654,
654.4,
666.4,
686.7,
689.3,
683.8,
698.6,
713.5,
710.3,
702.2,
699.2,
686.9,
695.4,
712.3,
712.4,
712.2,
711.2,
711.9,
696.7,
689.7,
666.6];

load = Dict()

load[1] = 2.5*0.01*loadraw1;
load[2] = 2.5*0.01*loadraw2;

wind = Dict()

wind[1] = 0.01*windraw1;
wind[2] = 0.01*windraw2;
=#

# %%
nscen = 12
# Out:
# 12

# %%
loaddf = DataFrame(CSV.File("./hourly_load_12scen.csv"))
base = 100.0;
factor = 1.35;

load = Dict()

for i = 1:nscen
    load[i] = [];
    for j = 1:24
        push!(load[i], factor/base*loaddf[j,i])
    end
end

# %%
load[12][24]
# Out:
# 12.564819396450002

# %%
winddf = DataFrame(CSV.File("./hourly_wind122_12scen.csv"))
base = 100.0;
factor = 1.0;

wind = Dict()

for i = 1:nscen
    wind[i] = [];
    for j = 1:24
        push!(wind[i], factor/base*winddf[j,i])
    end
end

# %%
wind[12][24]
# Out:
# 2.207

# %%
    println("Loading Models.")
    exmodel, submodel = load_in_models()
# Out:
# Loading Models.
# (A JuMP Model
# Feasibility problem with:
# Variables: 0
# Model mode: AUTOMATIC
# CachingOptimizer state: NO_OPTIMIZER
# Solver name: No optimizer attached., A JuMP Model
# Minimization problem with:
# Variables: 4440
# Objective function type: AffExpr
# `AffExpr`-in-`MathOptInterface.EqualTo{Float64}`: 2064 constraints
# `AffExpr`-in-`MathOptInterface.GreaterThan{Float64}`: 3504 constraints
# `AffExpr`-in-`MathOptInterface.LessThan{Float64}`: 2329 constraints
# `AffExpr`-in-`MathOptInterface.Interval{Float64}`: 1488 constraints
# Model mode: AUTOMATIC
# CachingOptimizer state: NO_OPTIMIZER
# Solver name: No optimizer attached.)

# %%
# Making branch constraints 0.8 of capacity, by multiplying the coefficient of interval constraint by 1.25 (=1/0.8)

for ts in timesteps
    for br in branches
        subcon = get_branch_interval(submodel, br, ts)
        conold = string(subcon)

        terms = JuMP.constraint_object(subcon).func.terms
        
        for (subvar, coeff) in terms
            JuMP.set_normalized_coefficient(subcon, subvar, 1.25*coeff)
        end
        
        #println(subcon, " ", conold)
        #println(JuMP.constraint_by_name(exmodel, exconname))
    end
end

# %%
ramp_frac = 1.0
# Out:
# 1.0

# %%
# set upper bound of ramping to ramp_frac * max generation.
# may do this as a function of uptime/downtime if we are keeping hourly
#=
for ts in timesteps
    if ts > 1
        for gen in gens
            
            subint = get_thermal_interval(submodel, gen, ts)
            subcon = get_ramp_ub(submodel, gen, ts)
            subold = string(subcon)

            terms = JuMP.constraint_object(subcon).func.terms
            value = JuMP.constraint_object(subint).set.upper

            for (subvar, coeff) in terms
                JuMP.set_normalized_rhs(subcon, ramp_frac*value)
            end
            #println(subold, " ", subcon)
        end
    end
end
=#

# %%
# set lower bound of ramping to ramp_frac * max generation.
# may do this as a function of uptime/downtime if we are keeping hourly
#=
for ts in timesteps
    if ts > 1
        for gen in gens
            
            subint = get_thermal_interval(submodel, gen, ts)
            subcon = get_ramp_lb(submodel, gen, ts)
            subold = string(subcon)

            terms = JuMP.constraint_object(subcon).func.terms
            value = JuMP.constraint_object(subint).set.upper

            for (subvar, coeff) in terms
                JuMP.set_normalized_rhs(subcon, -ramp_frac*value)
            end
            #println(subold, " ", subcon)
        end
    end
end
=#

# %%
#make no charging costs (as opposed to 18/MWh)
for bus in buses
    for ts in timesteps
        var = get_charging_variable(submodel,bus,ts)
        JuMP.set_objective_coefficient(submodel, var, 0.0)
    end
end

# %%
#change discharging costs (to that of Xiong and Singh)
for bus in buses
    for ts in timesteps
        var = get_discharging_variable(submodel,bus,ts)
        JuMP.set_objective_coefficient(submodel, var, 0.015*365.25*.01)
    end
end

# %%
#change loss of load cost to reflect ERCOT 8500/MWh
for bus in buses
    for ts in timesteps
        var = get_lossofload_variable(submodel,bus,ts)
        JuMP.set_objective_coefficient(submodel, var, 8000.0*100*365.25/1000000)
    end
end

# %%
# change cost of Power Rating to Xiong and Singh (adding in yearly fixed cost)
for bus in buses
    var = get_PR_variable(submodel,bus)
    JuMP.set_objective_coefficient(submodel, var, 56.12)
end

# %%
# change cost of Energy Rating to Xiong and Singh
for bus in buses
    var = get_ER_variable(submodel,bus)
    JuMP.set_objective_coefficient(submodel, var, 0.3)
end

# %%
ef, sub = construct_ef_model(exmodel, submodel, load, wind, nscen)
# Out:
# Adding first stage info.
# Adding second stage info...
# ...Scenario 1...
# ......Adjusting uncertainty...
# .........load balance...
# .........ptdf...
# .........wind upper bound...
# ......Adding variables...
# ......Adding constraints...
# ......Adding to objective function...
# ...Scenario 2...
# ......Adjusting uncertainty...
# .........load balance...
# .........ptdf...
# .........wind upper bound...
# ......Adding variables...
# ......Adding constraints...
# ......Adding to objective function...
# ...Scenario 3...
# ......Adjusting uncertainty...
# .........load balance...
# .........ptdf...
# .........wind upper bound...
# ......Adding variables...
# ......Adding constraints...
# ......Adding to objective function...
# ...Scenario 4...
# ......Adjusting uncertainty...
# .........load balance...
# .........ptdf...
# .........wind upper bound...
# ......Adding variables...
# ......Adding constraints...
# ......Adding to objective function...
# ...Scenario 5...
# ......Adjusting uncertainty...
# .........load balance...
# .........ptdf...
# .........wind upper bound...
# ......Adding variables...
# ......Adding constraints...
# ......Adding to objective function...
# ...Scenario 6...
# ......Adjusting uncertainty...
# .........load balance...
# .........ptdf...
# .........wind upper bound...
# ......Adding variables...
# ......Adding constraints...
# ......Adding to objective function...
# ...Scenario 7...
# ......Adjusting uncertainty...
# .........load balance...
# .........ptdf...
# .........wind upper bound...
# ......Adding variables...
# ......Adding constraints...
# ......Adding to objective function...
# ...Scenario 8...
# ......Adjusting uncertainty...
# .........load balance...
# .........ptdf...
# .........wind upper bound...
# ......Adding variables...
# ......Adding constraints...
# ......Adding to objective function...
# ...Scenario 9...
# ......Adjusting uncertainty...
# .........load balance...
# .........ptdf...
# .........wind upper bound...
# ......Adding variables...
# ......Adding constraints...
# ......Adding to objective function...
# ...Scenario 10...
# ......Adjusting uncertainty...
# .........load balance...
# .........ptdf...
# .........wind upper bound...
# ......Adding variables...
# ......Adding constraints...
# ......Adding to objective function...
# ...Scenario 11...
# ......Adjusting uncertainty...
# .........load balance...
# .........ptdf...
# .........wind upper bound...
# ......Adding variables...
# ......Adding constraints...
# ......Adding to objective function...
# ...Scenario 12...
# ......Adjusting uncertainty...
# .........load balance...
# .........ptdf...
# .........wind upper bound...
# ......Adding variables...
# ......Adding constraints...
# ......Adding to objective function...
# Setting objective function.
# Done.
# (A JuMP Model
# Minimization problem with:
# Variables: 52752
# Objective function type: AffExpr
# `AffExpr`-in-`MathOptInterface.EqualTo{Float64}`: 24768 constraints
# `AffExpr`-in-`MathOptInterface.GreaterThan{Float64}`: 41520 constraints
# `AffExpr`-in-`MathOptInterface.LessThan{Float64}`: 27673 constraints
# `AffExpr`-in-`MathOptInterface.Interval{Float64}`: 17856 constraints
# Model mode: AUTOMATIC
# CachingOptimizer state: NO_OPTIMIZER
# Solver name: No optimizer attached., A JuMP Model
# Minimization problem with:
# Variables: 4440
# Objective function type: AffExpr
# `AffExpr`-in-`MathOptInterface.EqualTo{Float64}`: 2064 constraints
# `AffExpr`-in-`MathOptInterface.GreaterThan{Float64}`: 3504 constraints
# `AffExpr`-in-`MathOptInterface.LessThan{Float64}`: 2329 constraints
# `AffExpr`-in-`MathOptInterface.Interval{Float64}`: 1488 constraints
# Model mode: AUTOMATIC
# CachingOptimizer state: NO_OPTIMIZER
# Solver name: No optimizer attached.)

# %%
#fixing energy to be 0 at start and end of day
for scen = 1:nscen
    for bus in buses
        
        JuMP.fix(get_stored_variable(ef,bus,1,scen),0.0)
        JuMP.fix(get_stored_variable(ef,bus,24,scen),0.0)
    end
end

# %%
JuMP.set_optimizer(ef, Gurobi.Optimizer)
# Out:
# Academic license - for non-commercial use only - expires 2022-08-19

# %%
JuMP.optimize!(ef)
# Out:
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with
#   58   5.99466270e+02  5.71843300e+02  2.38e-01 2.13e-07  4.39e-08     8s
#
# Barrier performed 58 iterations in 8.19 seconds
# Sub-optimal termination - objective 5.99692752e+02
#
# Crossover log...
#
#    30853 DPushes remaining with DInf 0.0000000e+00                 8s
#        0 DPushes remaining with DInf 0.0000000e+00                 9s
#
#     4032 Dual superbasic variables remain
#
#    16135 PPushes remaining with PInf 2.7328056e-06                 9s
#        0 PPushes remaining with PInf 0.0000000e+00                 9s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.1655884e+01      9s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    29140    5.9500486e+02   0.000000e+00   3.165588e+01      9s
#    31316    5.9303088e+02   0.000000e+00   0.000000e+00      9s
#
# Solved with barrier
# Solved in 31316 iterations and 9.22 seconds
# Optimal objective  5.930308806e+02
#
# User-callback calls 55115, time in user-callback 0.01 sec

# %%
vars = JuMP.all_variables(ef)

for i = 1:2*24
    
    println(vars[i], " ", JuMP.value(vars[i]))
end
# Out:
# UndefVarError: ef not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[28]:1
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1094

# %%
# check loss of load non-zeros
sum = 0
for s = 1:nscen
    println("Scenario $(s)")
    for ts in timesteps
        for bus in buses
            var = get_lossofload_variable(ef,bus,ts,s)
            if JuMP.value(var) > 0
                println(var, " ", JuMP.value(var))
                sum += JuMP.value(var)
            end
        end
    end
end
sum
# Out:
# Scenario 1
# Scenario 2
# Scenario 3
# Scenario 4
# Scenario 5
# Scenario 6
# Scenario 7
# LOL_{102,11}_7 1.0877632279378597
# LOL_{104,12}_7 2.5323210690993623
# LOL_{103,13}_7 3.611933287492476
# LOL_{105,13}_7 0.013747746877640132
# LOL_{103,14}_7 0.7450752262095941
# LOL_{117,14}_7 4.070877582522622
# LOL_{121,15}_7 5.676824097346502
# LOL_{106,16}_7 0.0071778617584445925
# LOL_{110,16}_7 6.021046715336831
# LOL_{104,17}_7 1.4171842045219956
# LOL_{117,17}_7 4.1240892402192335
# LOL_{111,18}_7 4.26075494980613
# LOL_{116,19}_7 3.275077925814324
# LOL_{111,20}_7 2.6379861431860365
# LOL_{101,21}_7 1.3410492947362571
# Scenario 8
# LOL_{121,13}_8 0.1496142393878287
# LOL_{106,14}_8 1.2222912462979862
# LOL_{116,15}_8 1.8271446605672483
# LOL_{105,16}_8 2.202875301955348
# LOL_{105,17}_8 1.8358049846716997
# LOL_{106,18}_8 1.860224510735056
# LOL_{117,19}_8 0.8390933961910351
# LOL_{101,20}_8 0.4571553589469308
# Scenario 9
# LOL_{124,14}_9 0.831220984295705
# LOL_{103,15}_9 0.5779551527897706
# LOL_{118,15}_9 0.5097318739422632
# LOL_{109,16}_9 1.0689730932584338
# LOL_{116,17}_9 0.3957961615744616
# Scenario 10
# LOL_{122,15}_10 0.2931029156622012
# LOL_{112,16}_10 0.2858561912045494
# Scenario 11
# Scenario 12
# 55.179748644345814

# %%
#JuMP.write_to_file(ef, "./ef_12scen_test.mps")
#JuMP.write_to_file(sub, "./sub_12scen_test.mps")

# %%
count = 0
for (var, coeff) in JuMP.objective_function(ef).terms
    count += 1
    if count > 1000 && count < 2000
    println(var, " ", coeff)
    end
end
# Out:
# Pdis_{117_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{118_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{119_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{120_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{121_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{122_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{123_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{124_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{101_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{102_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{103_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{104_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{105_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{106_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{107_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{108_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{109_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{110_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{111_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{112_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{113_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{114_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{115_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{116_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{117_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{118_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{119_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{120_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{121_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{122_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{123_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{124_STORAGE_1,19}_1 0.004565624999999999
# Pdis_{101_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{102_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{103_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{104_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{105_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{106_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{107_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{108_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{109_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{110_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{111_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{112_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{113_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{114_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{115_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{116_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{117_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{118_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{119_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{120_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{121_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{122_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{123_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{124_STORAGE_1,20}_1 0.004565624999999999
# Pdis_{101_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{102_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{103_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{104_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{105_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{106_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{107_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{108_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{109_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{110_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{111_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{112_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{113_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{114_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{115_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{116_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{117_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{118_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{119_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{120_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{121_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{122_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{123_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{124_STORAGE_1,21}_1 0.004565624999999999
# Pdis_{101_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{102_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{103_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{104_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{105_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{106_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{107_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{108_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{109_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{110_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{111_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{112_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{113_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{114_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{115_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{116_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{117_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{118_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{119_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{120_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{121_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{122_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{123_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{124_STORAGE_1,22}_1 0.004565624999999999
# Pdis_{101_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{102_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{103_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{104_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{105_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{106_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{107_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{108_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{109_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{110_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{111_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{112_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{113_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{114_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{115_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{116_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{117_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{118_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{119_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{120_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{121_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{122_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{123_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{124_STORAGE_1,23}_1 0.004565624999999999
# Pdis_{101_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{102_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{103_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{104_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{105_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{106_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{107_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{108_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{109_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{110_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{111_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{112_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{113_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{114_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{115_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{116_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{117_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{118_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{119_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{120_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{121_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{122_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{123_STORAGE_1,24}_1 0.004565624999999999
# Pdis_{124_STORAGE_1,24}_1 0.004565624999999999
# LOL_{101,1}_1 6.0874999999999995
# OL_{101,1}_1 6.0874999999999995
# LOL_{102,1}_1 6.0874999999999995
# OL_{102,1}_1 6.0874999999999995
# LOL_{103,1}_1 6.0874999999999995
# OL_{103,1}_1 6.0874999999999995
# LOL_{104,1}_1 6.0874999999999995
# OL_{104,1}_1 6.0874999999999995
# LOL_{105,1}_1 6.0874999999999995
# OL_{105,1}_1 6.0874999999999995
# LOL_{106,1}_1 6.0874999999999995
# OL_{106,1}_1 6.0874999999999995
# LOL_{107,1}_1 6.0874999999999995
# OL_{107,1}_1 6.0874999999999995
# LOL_{108,1}_1 6.0874999999999995
# OL_{108,1}_1 6.0874999999999995
# LOL_{109,1}_1 6.0874999999999995
# OL_{109,1}_1 6.0874999999999995
# LOL_{110,1}_1 6.0874999999999995
# OL_{110,1}_1 6.0874999999999995
# LOL_{111,1}_1 6.0874999999999995
# OL_{111,1}_1 6.0874999999999995
# LOL_{112,1}_1 6.0874999999999995
# OL_{112,1}_1 6.0874999999999995
# LOL_{113,1}_1 6.0874999999999995
# OL_{113,1}_1 6.0874999999999995
# LOL_{114,1}_1 6.0874999999999995
# OL_{114,1}_1 6.0874999999999995
# LOL_{115,1}_1 6.0874999999999995
# OL_{115,1}_1 6.0874999999999995
# LOL_{116,1}_1 6.0874999999999995
# OL_{116,1}_1 6.0874999999999995
# LOL_{117,1}_1 6.0874999999999995
# OL_{117,1}_1 6.0874999999999995
# LOL_{118,1}_1 6.0874999999999995
# OL_{118,1}_1 6.0874999999999995
# LOL_{119,1}_1 6.0874999999999995
# OL_{119,1}_1 6.0874999999999995
# LOL_{120,1}_1 6.0874999999999995
# OL_{120,1}_1 6.0874999999999995
# LOL_{121,1}_1 6.0874999999999995
# OL_{121,1}_1 6.0874999999999995
# LOL_{122,1}_1 6.0874999999999995
# OL_{122,1}_1 6.0874999999999995
# LOL_{123,1}_1 6.0874999999999995
# OL_{123,1}_1 6.0874999999999995
# LOL_{124,1}_1 6.0874999999999995
# OL_{124,1}_1 6.0874999999999995
# LOL_{101,2}_1 6.0874999999999995
# OL_{101,2}_1 6.0874999999999995
# LOL_{102,2}_1 6.0874999999999995
# OL_{102,2}_1 6.0874999999999995
# LOL_{103,2}_1 6.0874999999999995
# OL_{103,2}_1 6.0874999999999995
# LOL_{104,2}_1 6.0874999999999995
# OL_{104,2}_1 6.0874999999999995
# LOL_{105,2}_1 6.0874999999999995
# OL_{105,2}_1 6.0874999999999995
# LOL_{106,2}_1 6.0874999999999995
# OL_{106,2}_1 6.0874999999999995
# LOL_{107,2}_1 6.0874999999999995
# OL_{107,2}_1 6.0874999999999995
# LOL_{108,2}_1 6.0874999999999995
# OL_{108,2}_1 6.0874999999999995
# LOL_{109,2}_1 6.0874999999999995
# OL_{109,2}_1 6.0874999999999995
# LOL_{110,2}_1 6.0874999999999995
# OL_{110,2}_1 6.0874999999999995
# LOL_{111,2}_1 6.0874999999999995
# OL_{111,2}_1 6.0874999999999995
# LOL_{112,2}_1 6.0874999999999995
# OL_{112,2}_1 6.0874999999999995
# LOL_{113,2}_1 6.0874999999999995
# OL_{113,2}_1 6.0874999999999995
# LOL_{114,2}_1 6.0874999999999995
# OL_{114,2}_1 6.0874999999999995
# LOL_{115,2}_1 6.0874999999999995
# OL_{115,2}_1 6.0874999999999995
# LOL_{116,2}_1 6.0874999999999995
# OL_{116,2}_1 6.0874999999999995
# LOL_{117,2}_1 6.0874999999999995
# OL_{117,2}_1 6.0874999999999995
# LOL_{118,2}_1 6.0874999999999995
# OL_{118,2}_1 6.0874999999999995
# LOL_{119,2}_1 6.0874999999999995
# OL_{119,2}_1 6.0874999999999995
# LOL_{120,2}_1 6.0874999999999995
# OL_{120,2}_1 6.0874999999999995
# LOL_{121,2}_1 6.0874999999999995
# OL_{121,2}_1 6.0874999999999995
# LOL_{122,2}_1 6.0874999999999995
# OL_{122,2}_1 6.0874999999999995
# LOL_{123,2}_1 6.0874999999999995
# OL_{123,2}_1 6.0874999999999995
# LOL_{124,2}_1 6.0874999999999995
# OL_{124,2}_1 6.0874999999999995
# LOL_{101,3}_1 6.0874999999999995
# OL_{101,3}_1 6.0874999999999995
# LOL_{102,3}_1 6.0874999999999995
# OL_{102,3}_1 6.0874999999999995
# LOL_{103,3}_1 6.0874999999999995
# OL_{103,3}_1 6.0874999999999995
# LOL_{104,3}_1 6.0874999999999995
# OL_{104,3}_1 6.0874999999999995
# LOL_{105,3}_1 6.0874999999999995
# OL_{105,3}_1 6.0874999999999995
# LOL_{106,3}_1 6.0874999999999995
# OL_{106,3}_1 6.0874999999999995
# LOL_{107,3}_1 6.0874999999999995
# OL_{107,3}_1 6.0874999999999995
# LOL_{108,3}_1 6.0874999999999995
# OL_{108,3}_1 6.0874999999999995
# LOL_{109,3}_1 6.0874999999999995
# OL_{109,3}_1 6.0874999999999995
# LOL_{110,3}_1 6.0874999999999995
# OL_{110,3}_1 6.0874999999999995
# LOL_{111,3}_1 6.0874999999999995
# OL_{111,3}_1 6.0874999999999995
# LOL_{112,3}_1 6.0874999999999995
# OL_{112,3}_1 6.0874999999999995
# LOL_{113,3}_1 6.0874999999999995
# OL_{113,3}_1 6.0874999999999995
# LOL_{114,3}_1 6.0874999999999995
# LOL_{102,5}_1 6.0874999999999995
# OL_{102,5}_1 6.0874999999999995
# LOL_{103,5}_1 6.0874999999999995
# OL_{103,5}_1 6.0874999999999995
# LOL_{104,5}_1 6.0874999999999995
# OL_{104,5}_1 6.0874999999999995
# LOL_{105,5}_1 6.0874999999999995
# OL_{105,5}_1 6.0874999999999995
# LOL_{106,5}_1 6.0874999999999995
# OL_{106,5}_1 6.0874999999999995
# LOL_{107,5}_1 6.0874999999999995
# OL_{107,5}_1 6.0874999999999995
# LOL_{108,5}_1 6.0874999999999995
# OL_{108,5}_1 6.0874999999999995
# LOL_{109,5}_1 6.0874999999999995
# OL_{109,5}_1 6.0874999999999995
# LOL_{110,5}_1 6.0874999999999995
# OL_{110,5}_1 6.0874999999999995
# LOL_{111,5}_1 6.0874999999999995
# OL_{111,5}_1 6.0874999999999995
# LOL_{112,5}_1 6.0874999999999995
# OL_{112,5}_1 6.0874999999999995
# LOL_{113,5}_1 6.0874999999999995
# OL_{113,5}_1 6.0874999999999995
# LOL_{114,5}_1 6.0874999999999995
# OL_{114,5}_1 6.0874999999999995
# LOL_{115,5}_1 6.0874999999999995
# OL_{115,5}_1 6.0874999999999995
# LOL_{116,5}_1 6.0874999999999995
# OL_{116,5}_1 6.0874999999999995
# LOL_{117,5}_1 6.0874999999999995
# OL_{117,5}_1 6.0874999999999995
# LOL_{118,5}_1 6.0874999999999995
# OL_{118,5}_1 6.0874999999999995
# LOL_{119,5}_1 6.0874999999999995
# OL_{119,5}_1 6.0874999999999995
# LOL_{120,5}_1 6.0874999999999995
# OL_{120,5}_1 6.0874999999999995
# LOL_{121,5}_1 6.0874999999999995
# OL_{121,5}_1 6.0874999999999995
# LOL_{122,5}_1 6.0874999999999995
# OL_{122,5}_1 6.0874999999999995
# LOL_{123,5}_1 6.0874999999999995
# OL_{123,5}_1 6.0874999999999995
# LOL_{124,5}_1 6.0874999999999995
# OL_{124,5}_1 6.0874999999999995
# LOL_{101,6}_1 6.0874999999999995
# OL_{101,6}_1 6.0874999999999995
# LOL_{102,6}_1 6.0874999999999995
# OL_{102,6}_1 6.0874999999999995
# LOL_{103,6}_1 6.0874999999999995
# OL_{103,6}_1 6.0874999999999995
# LOL_{104,6}_1 6.0874999999999995
# OL_{104,6}_1 6.0874999999999995
# LOL_{105,6}_1 6.0874999999999995
# OL_{105,6}_1 6.0874999999999995
# LOL_{106,6}_1 6.0874999999999995
# OL_{106,6}_1 6.0874999999999995
# LOL_{107,6}_1 6.0874999999999995
# OL_{107,6}_1 6.0874999999999995
# LOL_{108,6}_1 6.0874999999999995
# OL_{108,6}_1 6.0874999999999995
# LOL_{109,6}_1 6.0874999999999995
# OL_{109,6}_1 6.0874999999999995
# LOL_{110,6}_1 6.0874999999999995
# OL_{110,6}_1 6.0874999999999995
# LOL_{111,6}_1 6.0874999999999995
# OL_{111,6}_1 6.0874999999999995
# LOL_{112,6}_1 6.0874999999999995
# OL_{112,6}_1 6.0874999999999995
# LOL_{113,6}_1 6.0874999999999995
# OL_{113,6}_1 6.0874999999999995
# LOL_{114,6}_1 6.0874999999999995
# OL_{114,6}_1 6.0874999999999995
# LOL_{115,6}_1 6.0874999999999995
# OL_{115,6}_1 6.0874999999999995
# LOL_{116,6}_1 6.0874999999999995
# OL_{116,6}_1 6.0874999999999995
# LOL_{117,6}_1 6.0874999999999995
# OL_{117,6}_1 6.0874999999999995
# LOL_{118,6}_1 6.0874999999999995
# OL_{118,6}_1 6.0874999999999995
# LOL_{119,6}_1 6.0874999999999995
# OL_{119,6}_1 6.0874999999999995
# LOL_{120,6}_1 6.0874999999999995
# OL_{120,6}_1 6.0874999999999995
# LOL_{121,6}_1 6.0874999999999995
# OL_{121,6}_1 6.0874999999999995
# LOL_{122,6}_1 6.0874999999999995
# OL_{122,6}_1 6.0874999999999995
# LOL_{123,6}_1 6.0874999999999995
# OL_{123,6}_1 6.0874999999999995
# LOL_{124,6}_1 6.0874999999999995
# OL_{124,6}_1 6.0874999999999995
# LOL_{101,7}_1 6.0874999999999995
# OL_{101,7}_1 6.0874999999999995
# LOL_{102,7}_1 6.0874999999999995
# OL_{102,7}_1 6.0874999999999995
# LOL_{103,7}_1 6.0874999999999995
# OL_{103,7}_1 6.0874999999999995
# LOL_{104,7}_1 6.0874999999999995
# OL_{104,7}_1 6.0874999999999995
# LOL_{105,7}_1 6.0874999999999995
# OL_{105,7}_1 6.0874999999999995
# LOL_{106,7}_1 6.0874999999999995
# OL_{106,7}_1 6.0874999999999995
# LOL_{107,7}_1 6.0874999999999995
# OL_{107,7}_1 6.0874999999999995
# LOL_{108,7}_1 6.0874999999999995
# OL_{108,7}_1 6.0874999999999995
# LOL_{109,7}_1 6.0874999999999995
# OL_{109,7}_1 6.0874999999999995
# LOL_{110,7}_1 6.0874999999999995
# OL_{110,7}_1 6.0874999999999995
# LOL_{111,7}_1 6.0874999999999995
# OL_{111,7}_1 6.0874999999999995
# LOL_{112,7}_1 6.0874999999999995
# OL_{112,7}_1 6.0874999999999995
# LOL_{113,7}_1 6.0874999999999995
# OL_{113,7}_1 6.0874999999999995
# LOL_{114,7}_1 6.0874999999999995
# OL_{114,7}_1 6.0874999999999995
# LOL_{115,7}_1 6.0874999999999995
# OL_{115,7}_1 6.0874999999999995
# LOL_{116,7}_1 6.0874999999999995
# OL_{116,7}_1 6.0874999999999995
# LOL_{117,7}_1 6.0874999999999995
# OL_{117,7}_1 6.0874999999999995
# LOL_{118,7}_1 6.0874999999999995
# OL_{118,7}_1 6.0874999999999995
# LOL_{119,7}_1 6.0874999999999995
# OL_{119,7}_1 6.0874999999999995
# LOL_{120,7}_1 6.0874999999999995
# OL_{120,7}_1 6.0874999999999995
# LOL_{121,7}_1 6.0874999999999995
# OL_{121,7}_1 6.0874999999999995
# LOL_{122,7}_1 6.0874999999999995
# OL_{122,7}_1 6.0874999999999995
# LOL_{123,7}_1 6.0874999999999995
# OL_{123,7}_1 6.0874999999999995
# LOL_{124,7}_1 6.0874999999999995
# OL_{124,7}_1 6.0874999999999995
# LOL_{101,8}_1 6.0874999999999995
# OL_{101,8}_1 6.0874999999999995
# OL_{113,9}_1 6.0874999999999995
# LOL_{114,9}_1 6.0874999999999995
# OL_{114,9}_1 6.0874999999999995
# LOL_{115,9}_1 6.0874999999999995
# OL_{115,9}_1 6.0874999999999995
# LOL_{116,9}_1 6.0874999999999995
# OL_{116,9}_1 6.0874999999999995
# LOL_{117,9}_1 6.0874999999999995
# OL_{117,9}_1 6.0874999999999995
# LOL_{118,9}_1 6.0874999999999995
# OL_{118,9}_1 6.0874999999999995
# LOL_{119,9}_1 6.0874999999999995
# OL_{119,9}_1 6.0874999999999995
# LOL_{120,9}_1 6.0874999999999995
# OL_{120,9}_1 6.0874999999999995
# LOL_{121,9}_1 6.0874999999999995
# OL_{121,9}_1 6.0874999999999995
# LOL_{122,9}_1 6.0874999999999995
# OL_{122,9}_1 6.0874999999999995
# LOL_{123,9}_1 6.0874999999999995
# OL_{123,9}_1 6.0874999999999995
# LOL_{124,9}_1 6.0874999999999995
# OL_{124,9}_1 6.0874999999999995
# LOL_{101,10}_1 6.0874999999999995
# OL_{101,10}_1 6.0874999999999995
# LOL_{102,10}_1 6.0874999999999995
# OL_{102,10}_1 6.0874999999999995
# LOL_{103,10}_1 6.0874999999999995
# OL_{103,10}_1 6.0874999999999995
# LOL_{104,10}_1 6.0874999999999995
# OL_{104,10}_1 6.0874999999999995
# LOL_{105,10}_1 6.0874999999999995
# OL_{105,10}_1 6.0874999999999995
# LOL_{106,10}_1 6.0874999999999995
# OL_{106,10}_1 6.0874999999999995
# LOL_{107,10}_1 6.0874999999999995
# OL_{107,10}_1 6.0874999999999995
# LOL_{108,10}_1 6.0874999999999995
# OL_{108,10}_1 6.0874999999999995
# LOL_{109,10}_1 6.0874999999999995
# OL_{109,10}_1 6.0874999999999995
# LOL_{110,10}_1 6.0874999999999995
# OL_{110,10}_1 6.0874999999999995
# LOL_{111,10}_1 6.0874999999999995
# OL_{111,10}_1 6.0874999999999995
# LOL_{112,10}_1 6.0874999999999995
# OL_{112,10}_1 6.0874999999999995
# LOL_{113,10}_1 6.0874999999999995
# OL_{113,10}_1 6.0874999999999995
# LOL_{114,10}_1 6.0874999999999995
# OL_{114,10}_1 6.0874999999999995
# LOL_{115,10}_1 6.0874999999999995
# OL_{115,10}_1 6.0874999999999995
# LOL_{116,10}_1 6.0874999999999995
# OL_{116,10}_1 6.0874999999999995
# LOL_{117,10}_1 6.0874999999999995
# OL_{117,10}_1 6.0874999999999995
# LOL_{118,10}_1 6.0874999999999995
# OL_{118,10}_1 6.0874999999999995
# LOL_{119,10}_1 6.0874999999999995
# OL_{119,10}_1 6.0874999999999995
# LOL_{120,10}_1 6.0874999999999995
# OL_{120,10}_1 6.0874999999999995
# LOL_{121,10}_1 6.0874999999999995
# OL_{121,10}_1 6.0874999999999995
# LOL_{122,10}_1 6.0874999999999995
# OL_{122,10}_1 6.0874999999999995
# LOL_{123,10}_1 6.0874999999999995
# OL_{123,10}_1 6.0874999999999995
# LOL_{124,10}_1 6.0874999999999995
# OL_{124,10}_1 6.0874999999999995
# LOL_{101,11}_1 6.0874999999999995
# OL_{101,11}_1 6.0874999999999995
# LOL_{102,11}_1 6.0874999999999995
# OL_{102,11}_1 6.0874999999999995
# LOL_{103,11}_1 6.0874999999999995
# OL_{103,11}_1 6.0874999999999995
# LOL_{104,11}_1 6.0874999999999995
# OL_{104,11}_1 6.0874999999999995
# LOL_{105,11}_1 6.0874999999999995
# OL_{105,11}_1 6.0874999999999995
# LOL_{106,11}_1 6.0874999999999995
# OL_{106,11}_1 6.0874999999999995
# LOL_{107,11}_1 6.0874999999999995
# OL_{107,11}_1 6.0874999999999995
# LOL_{108,11}_1 6.0874999999999995
# OL_{108,11}_1 6.0874999999999995
# LOL_{109,11}_1 6.0874999999999995
# OL_{109,11}_1 6.0874999999999995
# LOL_{110,11}_1 6.0874999999999995
# OL_{110,11}_1 6.0874999999999995
# LOL_{111,11}_1 6.0874999999999995
# OL_{111,11}_1 6.0874999999999995
# LOL_{112,11}_1 6.0874999999999995
# OL_{112,11}_1 6.0874999999999995
# LOL_{113,11}_1 6.0874999999999995
# OL_{113,11}_1 6.0874999999999995
# LOL_{114,11}_1 6.0874999999999995
# OL_{114,11}_1 6.0874999999999995
# LOL_{115,11}_1 6.0874999999999995
# OL_{115,11}_1 6.0874999999999995
# LOL_{116,11}_1 6.0874999999999995
# OL_{116,11}_1 6.0874999999999995
# LOL_{117,11}_1 6.0874999999999995
# OL_{117,11}_1 6.0874999999999995
# LOL_{118,11}_1 6.0874999999999995
# OL_{118,11}_1 6.0874999999999995
# LOL_{119,11}_1 6.0874999999999995
# OL_{119,11}_1 6.0874999999999995
# LOL_{120,11}_1 6.0874999999999995
# OL_{120,11}_1 6.0874999999999995
# LOL_{121,11}_1 6.0874999999999995
# OL_{121,11}_1 6.0874999999999995
# LOL_{122,11}_1 6.0874999999999995
# OL_{122,11}_1 6.0874999999999995
# LOL_{123,11}_1 6.0874999999999995
# OL_{123,11}_1 6.0874999999999995
# LOL_{124,11}_1 6.0874999999999995
# OL_{124,11}_1 6.0874999999999995
# LOL_{101,12}_1 6.0874999999999995
# OL_{101,12}_1 6.0874999999999995
# LOL_{102,12}_1 6.0874999999999995
# OL_{102,12}_1 6.0874999999999995
# LOL_{103,12}_1 6.0874999999999995
# OL_{103,12}_1 6.0874999999999995
# LOL_{104,12}_1 6.0874999999999995
# OL_{104,12}_1 6.0874999999999995
# LOL_{105,12}_1 6.0874999999999995
# OL_{105,12}_1 6.0874999999999995
# LOL_{106,12}_1 6.0874999999999995
# OL_{106,12}_1 6.0874999999999995
# LOL_{107,12}_1 6.0874999999999995
# OL_{107,12}_1 6.0874999999999995
# LOL_{108,12}_1 6.0874999999999995
# OL_{108,12}_1 6.0874999999999995
# LOL_{109,12}_1 6.0874999999999995
# OL_{109,12}_1 6.0874999999999995
# LOL_{110,12}_1 6.0874999999999995
# OL_{110,12}_1 6.0874999999999995
# LOL_{111,12}_1 6.0874999999999995
# OL_{111,12}_1 6.0874999999999995
# LOL_{112,12}_1 6.0874999999999995
# OL_{112,12}_1 6.0874999999999995
# LOL_{113,12}_1 6.0874999999999995
# OL_{113,12}_1 6.0874999999999995
# LOL_{114,12}_1 6.0874999999999995
# OL_{114,12}_1 6.0874999999999995
# LOL_{115,12}_1 6.0874999999999995
# OL_{115,12}_1 6.0874999999999995
# LOL_{116,12}_1 6.0874999999999995
# OL_{116,12}_1 6.0874999999999995
# LOL_{117,12}_1 6.0874999999999995
# OL_{117,12}_1 6.0874999999999995
# LOL_{118,12}_1 6.0874999999999995
# OL_{118,12}_1 6.0874999999999995
# LOL_{119,12}_1 6.0874999999999995
# OL_{119,12}_1 6.0874999999999995
# LOL_{120,12}_1 6.0874999999999995
# OL_{120,12}_1 6.0874999999999995
# LOL_{121,12}_1 6.0874999999999995
# OL_{121,12}_1 6.0874999999999995
# LOL_{122,12}_1 6.0874999999999995
# OL_{122,12}_1 6.0874999999999995
# LOL_{123,12}_1 6.0874999999999995
# OL_{123,12}_1 6.0874999999999995
# LOL_{124,12}_1 6.0874999999999995
# OL_{124,12}_1 6.0874999999999995
# LOL_{101,13}_1 6.0874999999999995
# OL_{101,13}_1 6.0874999999999995
# LOL_{102,13}_1 6.0874999999999995
# OL_{102,13}_1 6.0874999999999995
# LOL_{103,13}_1 6.0874999999999995
# OL_{103,13}_1 6.0874999999999995
# LOL_{104,13}_1 6.0874999999999995
# OL_{104,13}_1 6.0874999999999995
# LOL_{105,13}_1 6.0874999999999995
# OL_{105,13}_1 6.0874999999999995
# LOL_{106,13}_1 6.0874999999999995
# OL_{106,13}_1 6.0874999999999995
# LOL_{107,13}_1 6.0874999999999995
# OL_{107,13}_1 6.0874999999999995
# LOL_{108,13}_1 6.0874999999999995
# OL_{108,13}_1 6.0874999999999995
# LOL_{109,13}_1 6.0874999999999995
# OL_{109,13}_1 6.0874999999999995
# LOL_{110,13}_1 6.0874999999999995
# OL_{110,13}_1 6.0874999999999995
# LOL_{111,13}_1 6.0874999999999995
# OL_{111,13}_1 6.0874999999999995
# LOL_{112,13}_1 6.0874999999999995
# OL_{112,13}_1 6.0874999999999995
# LOL_{113,13}_1 6.0874999999999995
# OL_{113,13}_1 6.0874999999999995
# LOL_{114,13}_1 6.0874999999999995
# OL_{114,13}_1 6.0874999999999995
# LOL_{115,13}_1 6.0874999999999995
# OL_{115,13}_1 6.0874999999999995
# LOL_{116,13}_1 6.0874999999999995
# OL_{116,13}_1 6.0874999999999995
# LOL_{117,13}_1 6.0874999999999995
# OL_{117,13}_1 6.0874999999999995
# LOL_{118,13}_1 6.0874999999999995
# OL_{118,13}_1 6.0874999999999995
# LOL_{119,13}_1 6.0874999999999995
# OL_{119,13}_1 6.0874999999999995
# LOL_{120,13}_1 6.0874999999999995
# OL_{120,13}_1 6.0874999999999995
# LOL_{121,13}_1 6.0874999999999995
# OL_{121,13}_1 6.0874999999999995
# LOL_{122,13}_1 6.0874999999999995
# OL_{122,13}_1 6.0874999999999995
# LOL_{123,13}_1 6.0874999999999995
# OL_{123,13}_1 6.0874999999999995
# LOL_{124,13}_1 6.0874999999999995
# OL_{124,13}_1 6.0874999999999995
# LOL_{101,14}_1 6.0874999999999995
# OL_{101,14}_1 6.0874999999999995
# LOL_{102,14}_1 6.0874999999999995
# OL_{102,14}_1 6.0874999999999995
# LOL_{103,14}_1 6.0874999999999995
# OL_{103,14}_1 6.0874999999999995
# LOL_{104,14}_1 6.0874999999999995
# OL_{104,14}_1 6.0874999999999995
# LOL_{105,14}_1 6.0874999999999995
# OL_{105,14}_1 6.0874999999999995
# LOL_{106,14}_1 6.0874999999999995
# OL_{106,14}_1 6.0874999999999995
# LOL_{107,14}_1 6.0874999999999995
# OL_{107,14}_1 6.0874999999999995
# LOL_{108,14}_1 6.0874999999999995
# OL_{108,14}_1 6.0874999999999995
# LOL_{109,14}_1 6.0874999999999995
# OL_{109,14}_1 6.0874999999999995
# LOL_{110,14}_1 6.0874999999999995
# OL_{110,14}_1 6.0874999999999995
# LOL_{111,14}_1 6.0874999999999995
# OL_{111,14}_1 6.0874999999999995
# LOL_{112,14}_1 6.0874999999999995
# OL_{112,14}_1 6.0874999999999995
# LOL_{113,14}_1 6.0874999999999995
# OL_{113,14}_1 6.0874999999999995
# LOL_{114,14}_1 6.0874999999999995
# OL_{114,14}_1 6.0874999999999995
# LOL_{115,14}_1 6.0874999999999995
# OL_{115,14}_1 6.0874999999999995
# LOL_{116,14}_1 6.0874999999999995
# OL_{116,14}_1 6.0874999999999995
# LOL_{117,14}_1 6.0874999999999995
# OL_{117,14}_1 6.0874999999999995
# LOL_{118,14}_1 6.0874999999999995
# OL_{118,14}_1 6.0874999999999995
# LOL_{119,14}_1 6.0874999999999995
# OL_{119,14}_1 6.0874999999999995
# LOL_{120,14}_1 6.0874999999999995
# OL_{120,14}_1 6.0874999999999995
# LOL_{121,14}_1 6.0874999999999995
# OL_{121,14}_1 6.0874999999999995
# LOL_{122,14}_1 6.0874999999999995
# OL_{122,14}_1 6.0874999999999995
# LOL_{123,14}_1 6.0874999999999995
# OL_{123,14}_1 6.0874999999999995
# LOL_{124,14}_1 6.0874999999999995
# OL_{124,14}_1 6.0874999999999995
# LOL_{101,15}_1 6.0874999999999995
# OL_{101,15}_1 6.0874999999999995
# LOL_{102,15}_1 6.0874999999999995
# OL_{102,15}_1 6.0874999999999995
# LOL_{103,15}_1 6.0874999999999995
# OL_{103,15}_1 6.0874999999999995
# LOL_{104,15}_1 6.0874999999999995
# OL_{104,15}_1 6.0874999999999995
# LOL_{105,15}_1 6.0874999999999995
# OL_{105,15}_1 6.0874999999999995
# LOL_{106,15}_1 6.0874999999999995
# OL_{106,15}_1 6.0874999999999995
# LOL_{107,15}_1 6.0874999999999995
# OL_{107,15}_1 6.0874999999999995
# LOL_{108,15}_1 6.0874999999999995
# OL_{108,15}_1 6.0874999999999995
# LOL_{109,15}_1 6.0874999999999995
# OL_{109,15}_1 6.0874999999999995
# LOL_{110,15}_1 6.0874999999999995
# OL_{110,15}_1 6.0874999999999995
# LOL_{111,15}_1 6.0874999999999995
# OL_{111,15}_1 6.0874999999999995
# LOL_{112,15}_1 6.0874999999999995
# OL_{112,15}_1 6.0874999999999995
# LOL_{113,15}_1 6.0874999999999995
# OL_{113,15}_1 6.0874999999999995
# LOL_{114,15}_1 6.0874999999999995
# OL_{114,15}_1 6.0874999999999995
# LOL_{115,15}_1 6.0874999999999995
# OL_{115,15}_1 6.0874999999999995
# LOL_{116,15}_1 6.0874999999999995
# OL_{116,15}_1 6.0874999999999995
# LOL_{117,15}_1 6.0874999999999995
# OL_{117,15}_1 6.0874999999999995
# LOL_{118,15}_1 6.0874999999999995
# OL_{118,15}_1 6.0874999999999995
# LOL_{119,15}_1 6.0874999999999995
# OL_{119,15}_1 6.0874999999999995
# LOL_{120,15}_1 6.0874999999999995
# OL_{120,15}_1 6.0874999999999995
# LOL_{121,15}_1 6.0874999999999995
# OL_{121,15}_1 6.0874999999999995
# LOL_{122,15}_1 6.0874999999999995
# OL_{122,15}_1 6.0874999999999995
# LOL_{123,15}_1 6.0874999999999995
# OL_{123,15}_1 6.0874999999999995
# LOL_{124,15}_1 6.0874999999999995
# OL_{124,15}_1 6.0874999999999995
# LOL_{101,16}_1 6.0874999999999995
# OL_{101,16}_1 6.0874999999999995
# LOL_{102,16}_1 6.0874999999999995
# OL_{102,16}_1 6.0874999999999995
# LOL_{103,16}_1 6.0874999999999995
# OL_{103,16}_1 6.0874999999999995
# LOL_{104,16}_1 6.0874999999999995
# OL_{104,16}_1 6.0874999999999995
# LOL_{105,16}_1 6.0874999999999995
# OL_{105,16}_1 6.0874999999999995
# LOL_{106,16}_1 6.0874999999999995
# OL_{106,16}_1 6.0874999999999995
# LOL_{107,16}_1 6.0874999999999995
# OL_{107,16}_1 6.0874999999999995
# LOL_{108,16}_1 6.0874999999999995
# OL_{108,16}_1 6.0874999999999995
# LOL_{109,16}_1 6.0874999999999995
# OL_{109,16}_1 6.0874999999999995
# LOL_{110,16}_1 6.0874999999999995
# OL_{110,16}_1 6.0874999999999995
# LOL_{111,16}_1 6.0874999999999995
# OL_{111,16}_1 6.0874999999999995
# LOL_{112,16}_1 6.0874999999999995
# OL_{112,16}_1 6.0874999999999995
# LOL_{113,16}_1 6.0874999999999995
# OL_{113,16}_1 6.0874999999999995
# LOL_{114,16}_1 6.0874999999999995
# OL_{114,16}_1 6.0874999999999995
# LOL_{115,16}_1 6.0874999999999995
# OL_{115,16}_1 6.0874999999999995
# LOL_{116,16}_1 6.0874999999999995
# OL_{116,16}_1 6.0874999999999995
# LOL_{117,16}_1 6.0874999999999995
# OL_{117,16}_1 6.0874999999999995
# LOL_{118,16}_1 6.0874999999999995
# OL_{118,16}_1 6.0874999999999995
# LOL_{119,16}_1 6.0874999999999995
# OL_{119,16}_1 6.0874999999999995
# LOL_{120,16}_1 6.0874999999999995
# OL_{120,16}_1 6.0874999999999995
# LOL_{121,16}_1 6.0874999999999995
# OL_{121,16}_1 6.0874999999999995
# LOL_{122,16}_1 6.0874999999999995
# OL_{122,16}_1 6.0874999999999995
# LOL_{123,16}_1 6.0874999999999995
# OL_{123,16}_1 6.0874999999999995
# LOL_{124,16}_1 6.0874999999999995
# OL_{124,16}_1 6.0874999999999995
# LOL_{101,17}_1 6.0874999999999995
# OL_{101,17}_1 6.0874999999999995
# LOL_{102,17}_1 6.0874999999999995
# OL_{102,17}_1 6.0874999999999995
# LOL_{103,17}_1 6.0874999999999995
# OL_{103,17}_1 6.0874999999999995
# LOL_{104,17}_1 6.0874999999999995
# OL_{104,17}_1 6.0874999999999995
# LOL_{105,17}_1 6.0874999999999995
# OL_{105,17}_1 6.0874999999999995
# LOL_{106,17}_1 6.0874999999999995
# OL_{106,17}_1 6.0874999999999995
# LOL_{107,17}_1 6.0874999999999995
# OL_{107,17}_1 6.0874999999999995
# LOL_{108,17}_1 6.0874999999999995
# OL_{108,17}_1 6.0874999999999995
# LOL_{109,17}_1 6.0874999999999995
# OL_{109,17}_1 6.0874999999999995
# LOL_{110,17}_1 6.0874999999999995
# OL_{110,17}_1 6.0874999999999995
# LOL_{111,17}_1 6.0874999999999995
# OL_{111,17}_1 6.0874999999999995
# LOL_{112,17}_1 6.0874999999999995
# OL_{112,17}_1 6.0874999999999995
# LOL_{113,17}_1 6.0874999999999995
# OL_{113,17}_1 6.0874999999999995
# LOL_{114,17}_1 6.0874999999999995
# OL_{114,17}_1 6.0874999999999995
# LOL_{115,17}_1 6.0874999999999995
# OL_{115,17}_1 6.0874999999999995
# LOL_{116,17}_1 6.0874999999999995
# OL_{116,17}_1 6.0874999999999995
# LOL_{117,17}_1 6.0874999999999995
# OL_{117,17}_1 6.0874999999999995
# LOL_{118,17}_1 6.0874999999999995
# OL_{118,17}_1 6.0874999999999995
# LOL_{119,17}_1 6.0874999999999995
# OL_{119,17}_1 6.0874999999999995
# LOL_{120,17}_1 6.0874999999999995
# OL_{120,17}_1 6.0874999999999995
# LOL_{121,17}_1 6.0874999999999995
# OL_{121,17}_1 6.0874999999999995
# LOL_{122,17}_1 6.0874999999999995
# OL_{122,17}_1 6.0874999999999995
# LOL_{123,17}_1 6.0874999999999995
# OL_{123,17}_1 6.0874999999999995
# LOL_{124,17}_1 6.0874999999999995
# OL_{124,17}_1 6.0874999999999995
# LOL_{101,18}_1 6.0874999999999995
# OL_{101,18}_1 6.0874999999999995
# LOL_{102,18}_1 6.0874999999999995
# OL_{102,18}_1 6.0874999999999995
# LOL_{103,18}_1 6.0874999999999995
# OL_{103,18}_1 6.0874999999999995
# LOL_{104,18}_1 6.0874999999999995
# OL_{104,18}_1 6.0874999999999995
# LOL_{105,18}_1 6.0874999999999995
# OL_{105,18}_1 6.0874999999999995
# LOL_{106,18}_1 6.0874999999999995
# OL_{106,18}_1 6.0874999999999995
# LOL_{107,18}_1 6.0874999999999995
# OL_{107,18}_1 6.0874999999999995
# LOL_{108,18}_1 6.0874999999999995
# OL_{108,18}_1 6.0874999999999995
# LOL_{109,18}_1 6.0874999999999995
# OL_{109,18}_1 6.0874999999999995
# LOL_{110,18}_1 6.0874999999999995
# OL_{110,18}_1 6.0874999999999995
# LOL_{111,18}_1 6.0874999999999995
# OL_{111,18}_1 6.0874999999999995
# LOL_{112,18}_1 6.0874999999999995
# OL_{112,18}_1 6.0874999999999995
# LOL_{113,18}_1 6.0874999999999995
# OL_{113,18}_1 6.0874999999999995
# LOL_{114,18}_1 6.0874999999999995
# OL_{114,18}_1 6.0874999999999995
# LOL_{115,18}_1 6.0874999999999995
# OL_{115,18}_1 6.0874999999999995
# LOL_{116,18}_1 6.0874999999999995

# %%
0.7216938156252368/0.9021172695315459
# Out:
# 0.8

# %%
for (var, coeff) in JuMP.objective_function(sub).terms
    println(var, " ", coeff)
end
# Out:
# Pth_{123_STEAM_2,1} 0.9005022658968751
# Pth_{101_STEAM_3,1} 0.7057312506149999
# Pth_{123_CT_1,1} 1.247549007985875
# Pth_{113_CT_3,1} 1.257345677010375
# Pth_{102_STEAM_3,1} 0.7882917691839374
# Pth_{113_CT_2,1} 1.257345677010375
# Pth_{101_STEAM_4,1} 0.7057312506149999
# Pth_{113_CT_1,1} 1.257345677010375
# Pth_{113_CT_4,1} 1.257345677010375
# Pth_{118_CC_1,1} 1.0136002922595
# Pth_{115_STEAM_3,1} 0.8596177257217498
# Pth_{101_CT_1,1} 4.0067364450825
# Pth_{115_STEAM_2,1} 5.1377478554025
# Pth_{101_CT_2,1} 4.0067364450825
# Pth_{123_STEAM_3,1} 0.8278443767471249
# Pth_{123_CT_5,1} 1.247549007985875
# Pth_{116_STEAM_1,1} 0.8493869389923749
# Pth_{115_STEAM_1,1} 5.1377478554025
# Pth_{121_NUCLEAR_1,1} 0.2959803375
# Pth_{102_CT_2,1} 3.96959678229375
# Pth_{123_CT_4,1} 1.247549007985875
# Pth_{102_CT_1,1} 3.96959678229375
# Pth_{102_STEAM_4,1} 0.7882917691839374
# Pth_{107_CC_1,1} 0.9916642724872501
# Pth_{123_STEAM_2,2} 0.9005022658968751
# Pth_{101_STEAM_3,2} 0.7057312506149999
# Pth_{123_CT_1,2} 1.247549007985875
# Pth_{113_CT_3,2} 1.257345677010375
# Pth_{102_STEAM_3,2} 0.7882917691839374
# Pth_{113_CT_2,2} 1.257345677010375
# Pth_{101_STEAM_4,2} 0.7057312506149999
# Pth_{113_CT_1,2} 1.257345677010375
# Pth_{113_CT_4,2} 1.257345677010375
# Pth_{118_CC_1,2} 1.0136002922595
# Pth_{115_STEAM_3,2} 0.8596177257217498
# Pth_{101_CT_1,2} 4.0067364450825
# Pth_{115_STEAM_2,2} 5.1377478554025
# Pth_{101_CT_2,2} 4.0067364450825
# Pth_{123_STEAM_3,2} 0.8278443767471249
# Pth_{123_CT_5,2} 1.247549007985875
# Pth_{116_STEAM_1,2} 0.8493869389923749
# Pth_{115_STEAM_1,2} 5.1377478554025
# Pth_{121_NUCLEAR_1,2} 0.2959803375
# Pth_{102_CT_2,2} 3.96959678229375
# Pth_{123_CT_4,2} 1.247549007985875
# Pth_{102_CT_1,2} 3.96959678229375
# Pth_{102_STEAM_4,2} 0.7882917691839374
# Pth_{107_CC_1,2} 0.9916642724872501
# Pth_{123_STEAM_2,3} 0.9005022658968751
# Pth_{101_STEAM_3,3} 0.7057312506149999
# Pth_{123_CT_1,3} 1.247549007985875
# Pth_{113_CT_3,3} 1.257345677010375
# Pth_{102_STEAM_3,3} 0.7882917691839374
# Pth_{113_CT_2,3} 1.257345677010375
# Pth_{101_STEAM_4,3} 0.7057312506149999
# Pth_{113_CT_1,3} 1.257345677010375
# Pth_{113_CT_4,3} 1.257345677010375
# Pth_{118_CC_1,3} 1.0136002922595
# Pth_{115_STEAM_3,3} 0.8596177257217498
# Pth_{101_CT_1,3} 4.0067364450825
# Pth_{115_STEAM_2,3} 5.1377478554025
# Pth_{101_CT_2,3} 4.0067364450825
# Pth_{123_STEAM_3,3} 0.8278443767471249
# Pth_{123_CT_5,3} 1.247549007985875
# Pth_{116_STEAM_1,3} 0.8493869389923749
# Pth_{115_STEAM_1,3} 5.1377478554025
# Pth_{121_NUCLEAR_1,3} 0.2959803375
# Pth_{102_CT_2,3} 3.96959678229375
# Pth_{123_CT_4,3} 1.247549007985875
# Pth_{102_CT_1,3} 3.96959678229375
# Pth_{102_STEAM_4,3} 0.7882917691839374
# Pth_{107_CC_1,3} 0.9916642724872501
# Pth_{123_STEAM_2,4} 0.9005022658968751
# Pth_{101_STEAM_3,4} 0.7057312506149999
# Pth_{123_CT_1,4} 1.247549007985875
# Pth_{113_CT_3,4} 1.257345677010375
# Pth_{102_STEAM_3,4} 0.7882917691839374
# Pth_{113_CT_2,4} 1.257345677010375
# Pth_{101_STEAM_4,4} 0.7057312506149999
# Pth_{113_CT_1,4} 1.257345677010375
# Pth_{113_CT_4,4} 1.257345677010375
# Pth_{118_CC_1,4} 1.0136002922595
# Pth_{115_STEAM_3,4} 0.8596177257217498
# Pth_{101_CT_1,4} 4.0067364450825
# Pth_{115_STEAM_2,4} 5.1377478554025
# Pth_{101_CT_2,4} 4.0067364450825
# Pth_{123_STEAM_3,4} 0.8278443767471249
# Pth_{123_CT_5,4} 1.247549007985875
# Pth_{116_STEAM_1,4} 0.8493869389923749
# Pth_{115_STEAM_1,4} 5.1377478554025
# Pth_{121_NUCLEAR_1,4} 0.2959803375
# Pth_{102_CT_2,4} 3.96959678229375
# Pth_{123_CT_4,4} 1.247549007985875
# Pth_{102_CT_1,4} 3.96959678229375
# Pth_{102_STEAM_4,4} 0.7882917691839374
# Pth_{107_CC_1,4} 0.9916642724872501
# Pth_{123_STEAM_2,5} 0.9005022658968751
# Pth_{101_STEAM_3,5} 0.7057312506149999
# Pth_{123_CT_1,5} 1.247549007985875
# Pth_{113_CT_3,5} 1.257345677010375
# Pth_{102_STEAM_3,5} 0.7882917691839374
# Pth_{113_CT_2,5} 1.257345677010375
# Pth_{101_STEAM_4,5} 0.7057312506149999
# Pth_{113_CT_1,5} 1.257345677010375
# Pth_{113_CT_4,5} 1.257345677010375
# Pth_{118_CC_1,5} 1.0136002922595
# Pth_{115_STEAM_3,5} 0.8596177257217498
# Pth_{101_CT_1,5} 4.0067364450825
# Pth_{115_STEAM_2,5} 5.1377478554025
# Pth_{101_CT_2,5} 4.0067364450825
# Pth_{123_STEAM_3,5} 0.8278443767471249
# Pth_{123_CT_5,5} 1.247549007985875
# Pth_{116_STEAM_1,5} 0.8493869389923749
# Pth_{115_STEAM_1,5} 5.1377478554025
# Pth_{121_NUCLEAR_1,5} 0.2959803375
# Pth_{102_CT_2,5} 3.96959678229375
# Pth_{123_CT_4,5} 1.247549007985875
# Pth_{102_CT_1,5} 3.96959678229375
# Pth_{102_STEAM_4,5} 0.7882917691839374
# Pth_{107_CC_1,5} 0.9916642724872501
# Pth_{123_STEAM_2,6} 0.9005022658968751
# Pth_{101_STEAM_3,6} 0.7057312506149999
# Pth_{123_CT_1,6} 1.247549007985875
# Pth_{113_CT_3,6} 1.257345677010375
# Pth_{102_STEAM_3,6} 0.7882917691839374
# Pth_{113_CT_2,6} 1.257345677010375
# Pth_{101_STEAM_4,6} 0.7057312506149999
# Pth_{113_CT_1,6} 1.257345677010375
# Pth_{113_CT_4,6} 1.257345677010375
# Pth_{118_CC_1,6} 1.0136002922595
# Pth_{115_STEAM_3,6} 0.8596177257217498
# Pth_{101_CT_1,6} 4.0067364450825
# Pth_{115_STEAM_2,6} 5.1377478554025
# Pth_{101_CT_2,6} 4.0067364450825
# Pth_{123_STEAM_3,6} 0.8278443767471249
# Pth_{123_CT_5,6} 1.247549007985875
# Pth_{116_STEAM_1,6} 0.8493869389923749
# Pth_{115_STEAM_1,6} 5.1377478554025
# Pth_{121_NUCLEAR_1,6} 0.2959803375
# Pth_{102_CT_2,6} 3.96959678229375
# Pth_{123_CT_4,6} 1.247549007985875
# Pth_{102_CT_1,6} 3.96959678229375
# Pth_{102_STEAM_4,6} 0.7882917691839374
# Pth_{107_CC_1,6} 0.9916642724872501
# Pth_{123_STEAM_2,7} 0.9005022658968751
# Pth_{101_STEAM_3,7} 0.7057312506149999
# Pth_{123_CT_1,7} 1.247549007985875
# Pth_{113_CT_3,7} 1.257345677010375
# Pth_{102_STEAM_3,7} 0.7882917691839374
# Pth_{113_CT_2,7} 1.257345677010375
# Pth_{101_STEAM_4,7} 0.7057312506149999
# Pth_{113_CT_1,7} 1.257345677010375
# Pth_{113_CT_4,7} 1.257345677010375
# Pth_{118_CC_1,7} 1.0136002922595
# Pth_{115_STEAM_3,7} 0.8596177257217498
# Pth_{101_CT_1,7} 4.0067364450825
# Pth_{115_STEAM_2,7} 5.1377478554025
# Pth_{101_CT_2,7} 4.0067364450825
# Pth_{123_STEAM_3,7} 0.8278443767471249
# Pth_{123_CT_5,7} 1.247549007985875
# Pth_{116_STEAM_1,7} 0.8493869389923749
# Pth_{115_STEAM_1,7} 5.1377478554025
# Pth_{121_NUCLEAR_1,7} 0.2959803375
# Pth_{102_CT_2,7} 3.96959678229375
# Pth_{123_CT_4,7} 1.247549007985875
# Pth_{102_CT_1,7} 3.96959678229375
# Pth_{102_STEAM_4,7} 0.7882917691839374
# Pth_{107_CC_1,7} 0.9916642724872501
# Pth_{123_STEAM_2,8} 0.9005022658968751
# Pth_{101_STEAM_3,8} 0.7057312506149999
# Pth_{123_CT_1,8} 1.247549007985875
# Pth_{113_CT_3,8} 1.257345677010375
# Pth_{102_STEAM_3,8} 0.7882917691839374
# Pth_{113_CT_2,8} 1.257345677010375
# Pth_{101_STEAM_4,8} 0.7057312506149999
# Pth_{113_CT_1,8} 1.257345677010375
# Pth_{113_CT_4,8} 1.257345677010375
# Pth_{118_CC_1,8} 1.0136002922595
# Pth_{115_STEAM_3,8} 0.8596177257217498
# Pth_{101_CT_1,8} 4.0067364450825
# Pth_{115_STEAM_2,8} 5.1377478554025
# Pth_{101_CT_2,8} 4.0067364450825
# Pth_{123_STEAM_3,8} 0.8278443767471249
# Pth_{123_CT_5,8} 1.247549007985875
# Pth_{116_STEAM_1,8} 0.8493869389923749
# Pth_{115_STEAM_1,8} 5.1377478554025
# Pth_{121_NUCLEAR_1,8} 0.2959803375
# Pth_{102_CT_2,8} 3.96959678229375
# Pth_{123_CT_4,8} 1.247549007985875
# Pth_{102_CT_1,8} 3.96959678229375
# Pth_{102_STEAM_4,8} 0.7882917691839374
# Pth_{107_CC_1,8} 0.9916642724872501
# Pth_{123_STEAM_2,9} 0.9005022658968751
# Pth_{101_STEAM_3,9} 0.7057312506149999
# Pth_{123_CT_1,9} 1.247549007985875
# Pth_{113_CT_3,9} 1.257345677010375
# Pth_{102_STEAM_3,9} 0.7882917691839374
# Pth_{113_CT_2,9} 1.257345677010375
# Pth_{101_STEAM_4,9} 0.7057312506149999
# Pth_{113_CT_1,9} 1.257345677010375
# Pth_{113_CT_4,9} 1.257345677010375
# Pth_{118_CC_1,9} 1.0136002922595
# Pth_{115_STEAM_3,9} 0.8596177257217498
# Pth_{101_CT_1,9} 4.0067364450825
# Pth_{115_STEAM_2,9} 5.1377478554025
# Pth_{101_CT_2,9} 4.0067364450825
# Pth_{123_STEAM_3,9} 0.8278443767471249
# Pth_{123_CT_5,9} 1.247549007985875
# Pth_{116_STEAM_1,9} 0.8493869389923749
# Pth_{115_STEAM_1,9} 5.1377478554025
# Pth_{121_NUCLEAR_1,9} 0.2959803375
# Pth_{102_CT_2,9} 3.96959678229375
# Pth_{123_CT_4,9} 1.247549007985875
# Pth_{102_CT_1,9} 3.96959678229375
# Pth_{102_STEAM_4,9} 0.7882917691839374
# Pth_{107_CC_1,9} 0.9916642724872501
# Pth_{123_STEAM_2,10} 0.9005022658968751
# Pth_{101_STEAM_3,10} 0.7057312506149999
# Pth_{123_CT_1,10} 1.247549007985875
# Pth_{113_CT_3,10} 1.257345677010375
# Pth_{102_STEAM_3,10} 0.7882917691839374
# Pth_{113_CT_2,10} 1.257345677010375
# Pth_{101_STEAM_4,10} 0.7057312506149999
# Pth_{113_CT_1,10} 1.257345677010375
# Pth_{113_CT_4,10} 1.257345677010375
# Pth_{118_CC_1,10} 1.0136002922595
# Pth_{115_STEAM_3,10} 0.8596177257217498
# Pth_{101_CT_1,10} 4.0067364450825
# Pth_{115_STEAM_2,10} 5.1377478554025
# Pth_{101_CT_2,10} 4.0067364450825
# Pth_{123_STEAM_3,10} 0.8278443767471249
# Pth_{123_CT_5,10} 1.247549007985875
# Pth_{116_STEAM_1,10} 0.8493869389923749
# Pth_{115_STEAM_1,10} 5.1377478554025
# Pth_{121_NUCLEAR_1,10} 0.2959803375
# Pth_{102_CT_2,10} 3.96959678229375
# Pth_{123_CT_4,10} 1.247549007985875
# Pth_{102_CT_1,10} 3.96959678229375
# Pth_{102_STEAM_4,10} 0.7882917691839374
# Pth_{107_CC_1,10} 0.9916642724872501
# Pth_{123_STEAM_2,11} 0.9005022658968751
# Pth_{101_STEAM_3,11} 0.7057312506149999
# Pth_{123_CT_1,11} 1.247549007985875
# Pth_{113_CT_3,11} 1.257345677010375
# Pth_{102_STEAM_3,11} 0.7882917691839374
# Pth_{113_CT_2,11} 1.257345677010375
# Pth_{101_STEAM_4,11} 0.7057312506149999
# Pth_{113_CT_1,11} 1.257345677010375
# Pth_{113_CT_4,11} 1.257345677010375
# Pth_{118_CC_1,11} 1.0136002922595
# Pth_{115_STEAM_3,11} 0.8596177257217498
# Pth_{101_CT_1,11} 4.0067364450825
# Pth_{115_STEAM_2,11} 5.1377478554025
# Pth_{101_CT_2,11} 4.0067364450825
# Pth_{123_STEAM_3,11} 0.8278443767471249
# Pth_{123_CT_5,11} 1.247549007985875
# Pth_{116_STEAM_1,11} 0.8493869389923749
# Pth_{115_STEAM_1,11} 5.1377478554025
# Pth_{121_NUCLEAR_1,11} 0.2959803375
# Pth_{102_CT_2,11} 3.96959678229375
# Pth_{123_CT_4,11} 1.247549007985875
# Pth_{102_CT_1,11} 3.96959678229375
# Pth_{102_STEAM_4,11} 0.7882917691839374
# Pth_{107_CC_1,11} 0.9916642724872501
# Pth_{123_STEAM_2,12} 0.9005022658968751
# Pth_{101_STEAM_3,12} 0.7057312506149999
# Pth_{123_CT_1,12} 1.247549007985875
# Pth_{113_CT_3,12} 1.257345677010375
# Pth_{102_STEAM_3,12} 0.7882917691839374
# Pth_{113_CT_2,12} 1.257345677010375
# Pth_{101_STEAM_4,12} 0.7057312506149999
# Pth_{113_CT_1,12} 1.257345677010375
# Pth_{113_CT_4,12} 1.257345677010375
# Pth_{118_CC_1,12} 1.0136002922595
# Pth_{115_STEAM_3,12} 0.8596177257217498
# Pth_{101_CT_1,12} 4.0067364450825
# Pth_{115_STEAM_2,12} 5.1377478554025
# Pth_{101_CT_2,12} 4.0067364450825
# Pth_{123_STEAM_3,12} 0.8278443767471249
# Pth_{123_CT_5,12} 1.247549007985875
# Pth_{116_STEAM_1,12} 0.8493869389923749
# Pth_{115_STEAM_1,12} 5.1377478554025
# Pth_{121_NUCLEAR_1,12} 0.2959803375
# Pth_{102_CT_2,12} 3.96959678229375
# Pth_{123_CT_4,12} 1.247549007985875
# Pth_{102_CT_1,12} 3.96959678229375
# Pth_{102_STEAM_4,12} 0.7882917691839374
# Pth_{107_CC_1,12} 0.9916642724872501
# Pth_{123_STEAM_2,13} 0.9005022658968751
# Pth_{101_STEAM_3,13} 0.7057312506149999
# Pth_{123_CT_1,13} 1.247549007985875
# Pth_{113_CT_3,13} 1.257345677010375
# Pth_{102_STEAM_3,13} 0.7882917691839374
# Pth_{113_CT_2,13} 1.257345677010375
# Pth_{101_STEAM_4,13} 0.7057312506149999
# Pth_{113_CT_1,13} 1.257345677010375
# Pth_{113_CT_4,13} 1.257345677010375
# Pth_{118_CC_1,13} 1.0136002922595
# Pth_{115_STEAM_3,13} 0.8596177257217498
# Pth_{101_CT_1,13} 4.0067364450825
# Pth_{115_STEAM_2,13} 5.1377478554025
# Pth_{101_CT_2,13} 4.0067364450825
# Pth_{123_STEAM_3,13} 0.8278443767471249
# Pth_{123_CT_5,13} 1.247549007985875
# Pth_{116_STEAM_1,13} 0.8493869389923749
# Pth_{115_STEAM_1,13} 5.1377478554025
# Pth_{121_NUCLEAR_1,13} 0.2959803375
# Pth_{102_CT_2,13} 3.96959678229375
# Pth_{123_CT_4,13} 1.247549007985875
# Pth_{102_CT_1,13} 3.96959678229375
# Pth_{102_STEAM_4,13} 0.7882917691839374
# Pth_{107_CC_1,13} 0.9916642724872501
# Pth_{123_STEAM_2,14} 0.9005022658968751
# Pth_{101_STEAM_3,14} 0.7057312506149999
# Pth_{123_CT_1,14} 1.247549007985875
# Pth_{113_CT_3,14} 1.257345677010375
# Pth_{102_STEAM_3,14} 0.7882917691839374
# Pth_{113_CT_2,14} 1.257345677010375
# Pth_{101_STEAM_4,14} 0.7057312506149999
# Pth_{113_CT_1,14} 1.257345677010375
# Pth_{113_CT_4,14} 1.257345677010375
# Pth_{118_CC_1,14} 1.0136002922595
# Pth_{115_STEAM_3,14} 0.8596177257217498
# Pth_{101_CT_1,14} 4.0067364450825
# Pth_{115_STEAM_2,14} 5.1377478554025
# Pth_{101_CT_2,14} 4.0067364450825
# Pth_{123_STEAM_3,14} 0.8278443767471249
# Pth_{123_CT_5,14} 1.247549007985875
# Pth_{116_STEAM_1,14} 0.8493869389923749
# Pth_{115_STEAM_1,14} 5.1377478554025
# Pth_{121_NUCLEAR_1,14} 0.2959803375
# Pth_{102_CT_2,14} 3.96959678229375
# Pth_{123_CT_4,14} 1.247549007985875
# Pth_{102_CT_1,14} 3.96959678229375
# Pth_{102_STEAM_4,14} 0.7882917691839374
# Pth_{107_CC_1,14} 0.9916642724872501
# Pth_{123_STEAM_2,15} 0.9005022658968751
# Pth_{101_STEAM_3,15} 0.7057312506149999
# Pth_{123_CT_1,15} 1.247549007985875
# Pth_{113_CT_3,15} 1.257345677010375
# Pth_{102_STEAM_3,15} 0.7882917691839374
# Pth_{113_CT_2,15} 1.257345677010375
# Pth_{101_STEAM_4,15} 0.7057312506149999
# Pth_{113_CT_1,15} 1.257345677010375
# Pth_{113_CT_4,15} 1.257345677010375
# Pth_{118_CC_1,15} 1.0136002922595
# Pth_{115_STEAM_3,15} 0.8596177257217498
# Pth_{101_CT_1,15} 4.0067364450825
# Pth_{115_STEAM_2,15} 5.1377478554025
# Pth_{101_CT_2,15} 4.0067364450825
# Pth_{123_STEAM_3,15} 0.8278443767471249
# Pth_{123_CT_5,15} 1.247549007985875
# Pth_{116_STEAM_1,15} 0.8493869389923749
# Pth_{115_STEAM_1,15} 5.1377478554025
# Pth_{121_NUCLEAR_1,15} 0.2959803375
# Pth_{102_CT_2,15} 3.96959678229375
# Pth_{123_CT_4,15} 1.247549007985875
# Pth_{102_CT_1,15} 3.96959678229375
# Pth_{102_STEAM_4,15} 0.7882917691839374
# Pth_{107_CC_1,15} 0.9916642724872501
# Pth_{123_STEAM_2,16} 0.9005022658968751
# Pth_{101_STEAM_3,16} 0.7057312506149999
# Pth_{123_CT_1,16} 1.247549007985875
# Pth_{113_CT_3,16} 1.257345677010375
# Pth_{102_STEAM_3,16} 0.7882917691839374
# Pth_{113_CT_2,16} 1.257345677010375
# Pth_{101_STEAM_4,16} 0.7057312506149999
# Pth_{113_CT_1,16} 1.257345677010375
# Pth_{113_CT_4,16} 1.257345677010375
# Pth_{118_CC_1,16} 1.0136002922595
# Pth_{115_STEAM_3,16} 0.8596177257217498
# Pth_{101_CT_1,16} 4.0067364450825
# Pth_{115_STEAM_2,16} 5.1377478554025
# Pth_{101_CT_2,16} 4.0067364450825
# Pth_{123_STEAM_3,16} 0.8278443767471249
# Pth_{123_CT_5,16} 1.247549007985875
# Pth_{116_STEAM_1,16} 0.8493869389923749
# Pth_{115_STEAM_1,16} 5.1377478554025
# Pth_{121_NUCLEAR_1,16} 0.2959803375
# Pth_{102_CT_2,16} 3.96959678229375
# Pth_{123_CT_4,16} 1.247549007985875
# Pth_{102_CT_1,16} 3.96959678229375
# Pth_{102_STEAM_4,16} 0.7882917691839374
# Pth_{107_CC_1,16} 0.9916642724872501
# Pth_{123_STEAM_2,17} 0.9005022658968751
# Pth_{101_STEAM_3,17} 0.7057312506149999
# Pth_{123_CT_1,17} 1.247549007985875
# Pth_{113_CT_3,17} 1.257345677010375
# Pth_{102_STEAM_3,17} 0.7882917691839374
# Pth_{113_CT_2,17} 1.257345677010375
# Pth_{101_STEAM_4,17} 0.7057312506149999
# Pth_{113_CT_1,17} 1.257345677010375
# Pth_{113_CT_4,17} 1.257345677010375
# Pth_{118_CC_1,17} 1.0136002922595
# Pth_{115_STEAM_3,17} 0.8596177257217498
# Pth_{101_CT_1,17} 4.0067364450825
# Pth_{115_STEAM_2,17} 5.1377478554025
# Pth_{101_CT_2,17} 4.0067364450825
# Pth_{123_STEAM_3,17} 0.8278443767471249
# Pth_{123_CT_5,17} 1.247549007985875
# Pth_{116_STEAM_1,17} 0.8493869389923749
# Pth_{115_STEAM_1,17} 5.1377478554025
# Pth_{121_NUCLEAR_1,17} 0.2959803375
# Pth_{102_CT_2,17} 3.96959678229375
# Pth_{123_CT_4,17} 1.247549007985875
# Pth_{102_CT_1,17} 3.96959678229375
# Pth_{102_STEAM_4,17} 0.7882917691839374
# Pth_{107_CC_1,17} 0.9916642724872501
# Pth_{123_STEAM_2,18} 0.9005022658968751
# Pth_{101_STEAM_3,18} 0.7057312506149999
# Pth_{123_CT_1,18} 1.247549007985875
# Pth_{113_CT_3,18} 1.257345677010375
# Pth_{102_STEAM_3,18} 0.7882917691839374
# Pth_{113_CT_2,18} 1.257345677010375
# Pth_{101_STEAM_4,18} 0.7057312506149999
# Pth_{113_CT_1,18} 1.257345677010375
# Pth_{113_CT_4,18} 1.257345677010375
# Pth_{118_CC_1,18} 1.0136002922595
# Pth_{115_STEAM_3,18} 0.8596177257217498
# Pth_{101_CT_1,18} 4.0067364450825
# Pth_{115_STEAM_2,18} 5.1377478554025
# Pth_{101_CT_2,18} 4.0067364450825
# Pth_{123_STEAM_3,18} 0.8278443767471249
# Pth_{123_CT_5,18} 1.247549007985875
# Pth_{116_STEAM_1,18} 0.8493869389923749
# Pth_{115_STEAM_1,18} 5.1377478554025
# Pth_{121_NUCLEAR_1,18} 0.2959803375
# Pth_{102_CT_2,18} 3.96959678229375
# Pth_{123_CT_4,18} 1.247549007985875
# Pth_{102_CT_1,18} 3.96959678229375
# Pth_{102_STEAM_4,18} 0.7882917691839374
# Pth_{107_CC_1,18} 0.9916642724872501
# Pth_{123_STEAM_2,19} 0.9005022658968751
# Pth_{101_STEAM_3,19} 0.7057312506149999
# Pth_{123_CT_1,19} 1.247549007985875
# Pth_{113_CT_3,19} 1.257345677010375
# Pth_{102_STEAM_3,19} 0.7882917691839374
# Pth_{113_CT_2,19} 1.257345677010375
# Pth_{101_STEAM_4,19} 0.7057312506149999
# Pth_{113_CT_1,19} 1.257345677010375
# Pth_{113_CT_4,19} 1.257345677010375
# Pth_{118_CC_1,19} 1.0136002922595
# Pth_{115_STEAM_3,19} 0.8596177257217498
# Pth_{101_CT_1,19} 4.0067364450825
# Pth_{115_STEAM_2,19} 5.1377478554025
# Pth_{101_CT_2,19} 4.0067364450825
# Pth_{123_STEAM_3,19} 0.8278443767471249
# Pth_{123_CT_5,19} 1.247549007985875
# Pth_{116_STEAM_1,19} 0.8493869389923749
# Pth_{115_STEAM_1,19} 5.1377478554025
# Pth_{121_NUCLEAR_1,19} 0.2959803375
# Pth_{102_CT_2,19} 3.96959678229375
# Pth_{123_CT_4,19} 1.247549007985875
# Pth_{102_CT_1,19} 3.96959678229375
# Pth_{102_STEAM_4,19} 0.7882917691839374
# Pth_{107_CC_1,19} 0.9916642724872501
# Pth_{123_STEAM_2,20} 0.9005022658968751
# Pth_{101_STEAM_3,20} 0.7057312506149999
# Pth_{123_CT_1,20} 1.247549007985875
# Pth_{113_CT_3,20} 1.257345677010375
# Pth_{102_STEAM_3,20} 0.7882917691839374
# Pth_{113_CT_2,20} 1.257345677010375
# Pth_{101_STEAM_4,20} 0.7057312506149999
# Pth_{113_CT_1,20} 1.257345677010375
# Pth_{113_CT_4,20} 1.257345677010375
# Pth_{118_CC_1,20} 1.0136002922595
# Pth_{115_STEAM_3,20} 0.8596177257217498
# Pth_{101_CT_1,20} 4.0067364450825
# Pth_{115_STEAM_2,20} 5.1377478554025
# Pth_{101_CT_2,20} 4.0067364450825
# Pth_{123_STEAM_3,20} 0.8278443767471249
# Pth_{123_CT_5,20} 1.247549007985875
# Pth_{116_STEAM_1,20} 0.8493869389923749
# Pth_{115_STEAM_1,20} 5.1377478554025
# Pth_{121_NUCLEAR_1,20} 0.2959803375
# Pth_{102_CT_2,20} 3.96959678229375
# Pth_{123_CT_4,20} 1.247549007985875
# Pth_{102_CT_1,20} 3.96959678229375
# Pth_{102_STEAM_4,20} 0.7882917691839374
# Pth_{107_CC_1,20} 0.9916642724872501
# Pth_{123_STEAM_2,21} 0.9005022658968751
# Pth_{101_STEAM_3,21} 0.7057312506149999
# Pth_{123_CT_1,21} 1.247549007985875
# Pth_{113_CT_3,21} 1.257345677010375
# Pth_{102_STEAM_3,21} 0.7882917691839374
# Pth_{113_CT_2,21} 1.257345677010375
# Pth_{101_STEAM_4,21} 0.7057312506149999
# Pth_{113_CT_1,21} 1.257345677010375
# Pth_{113_CT_4,21} 1.257345677010375
# Pth_{118_CC_1,21} 1.0136002922595
# Pth_{115_STEAM_3,21} 0.8596177257217498
# Pth_{101_CT_1,21} 4.0067364450825
# Pth_{115_STEAM_2,21} 5.1377478554025
# Pth_{101_CT_2,21} 4.0067364450825
# Pth_{123_STEAM_3,21} 0.8278443767471249
# Pth_{123_CT_5,21} 1.247549007985875
# Pth_{116_STEAM_1,21} 0.8493869389923749
# Pth_{115_STEAM_1,21} 5.1377478554025
# Pth_{121_NUCLEAR_1,21} 0.2959803375
# Pth_{102_CT_2,21} 3.96959678229375
# Pth_{123_CT_4,21} 1.247549007985875
# Pth_{102_CT_1,21} 3.96959678229375
# Pth_{102_STEAM_4,21} 0.7882917691839374
# Pth_{107_CC_1,21} 0.9916642724872501
# Pth_{123_STEAM_2,22} 0.9005022658968751
# Pth_{101_STEAM_3,22} 0.7057312506149999
# Pth_{123_CT_1,22} 1.247549007985875
# Pth_{113_CT_3,22} 1.257345677010375
# Pth_{102_STEAM_3,22} 0.7882917691839374
# Pth_{113_CT_2,22} 1.257345677010375
# Pth_{101_STEAM_4,22} 0.7057312506149999
# Pth_{113_CT_1,22} 1.257345677010375
# Pth_{113_CT_4,22} 1.257345677010375
# Pth_{118_CC_1,22} 1.0136002922595
# Pth_{115_STEAM_3,22} 0.8596177257217498
# Pth_{101_CT_1,22} 4.0067364450825
# Pth_{115_STEAM_2,22} 5.1377478554025
# Pth_{101_CT_2,22} 4.0067364450825
# Pth_{123_STEAM_3,22} 0.8278443767471249
# Pth_{123_CT_5,22} 1.247549007985875
# Pth_{116_STEAM_1,22} 0.8493869389923749
# Pth_{115_STEAM_1,22} 5.1377478554025
# Pth_{121_NUCLEAR_1,22} 0.2959803375
# Pth_{102_CT_2,22} 3.96959678229375
# Pth_{123_CT_4,22} 1.247549007985875
# Pth_{102_CT_1,22} 3.96959678229375
# Pth_{102_STEAM_4,22} 0.7882917691839374
# Pth_{107_CC_1,22} 0.9916642724872501
# Pth_{123_STEAM_2,23} 0.9005022658968751
# Pth_{101_STEAM_3,23} 0.7057312506149999
# Pth_{123_CT_1,23} 1.247549007985875
# Pth_{113_CT_3,23} 1.257345677010375
# Pth_{102_STEAM_3,23} 0.7882917691839374
# Pth_{113_CT_2,23} 1.257345677010375
# Pth_{101_STEAM_4,23} 0.7057312506149999
# Pth_{113_CT_1,23} 1.257345677010375
# Pth_{113_CT_4,23} 1.257345677010375
# Pth_{118_CC_1,23} 1.0136002922595
# Pth_{115_STEAM_3,23} 0.8596177257217498
# Pth_{101_CT_1,23} 4.0067364450825
# Pth_{115_STEAM_2,23} 5.1377478554025
# Pth_{101_CT_2,23} 4.0067364450825
# Pth_{123_STEAM_3,23} 0.8278443767471249
# Pth_{123_CT_5,23} 1.247549007985875
# Pth_{116_STEAM_1,23} 0.8493869389923749
# Pth_{115_STEAM_1,23} 5.1377478554025
# Pth_{121_NUCLEAR_1,23} 0.2959803375
# Pth_{102_CT_2,23} 3.96959678229375
# Pth_{123_CT_4,23} 1.247549007985875
# Pth_{102_CT_1,23} 3.96959678229375
# Pth_{102_STEAM_4,23} 0.7882917691839374
# Pth_{107_CC_1,23} 0.9916642724872501
# Pth_{123_STEAM_2,24} 0.9005022658968751
# Pth_{101_STEAM_3,24} 0.7057312506149999
# Pth_{123_CT_1,24} 1.247549007985875
# Pth_{113_CT_3,24} 1.257345677010375
# Pth_{102_STEAM_3,24} 0.7882917691839374
# Pth_{113_CT_2,24} 1.257345677010375
# Pth_{101_STEAM_4,24} 0.7057312506149999
# Pth_{113_CT_1,24} 1.257345677010375
# Pth_{113_CT_4,24} 1.257345677010375
# Pth_{118_CC_1,24} 1.0136002922595
# Pth_{115_STEAM_3,24} 0.8596177257217498
# Pth_{101_CT_1,24} 4.0067364450825
# Pth_{115_STEAM_2,24} 5.1377478554025
# Pth_{101_CT_2,24} 4.0067364450825
# Pth_{123_STEAM_3,24} 0.8278443767471249
# Pth_{123_CT_5,24} 1.247549007985875
# Pth_{116_STEAM_1,24} 0.8493869389923749
# Pth_{115_STEAM_1,24} 5.1377478554025
# Pth_{121_NUCLEAR_1,24} 0.2959803375
# Pth_{102_CT_2,24} 3.96959678229375
# Pth_{123_CT_4,24} 1.247549007985875
# Pth_{102_CT_1,24} 3.96959678229375
# Pth_{102_STEAM_4,24} 0.7882917691839374
# Pth_{107_CC_1,24} 0.9916642724872501
# Pch_{101_STORAGE_1,1} 0.036524999999999995
# Pch_{102_STORAGE_1,1} 0.036524999999999995
# Pch_{103_STORAGE_1,1} 0.036524999999999995
# Pch_{104_STORAGE_1,1} 0.036524999999999995
# Pch_{105_STORAGE_1,1} 0.036524999999999995
# Pch_{106_STORAGE_1,1} 0.036524999999999995
# Pch_{107_STORAGE_1,1} 0.036524999999999995
# Pch_{108_STORAGE_1,1} 0.036524999999999995
# Pch_{109_STORAGE_1,1} 0.036524999999999995
# Pch_{110_STORAGE_1,1} 0.036524999999999995
# Pch_{111_STORAGE_1,1} 0.036524999999999995
# Pch_{112_STORAGE_1,1} 0.036524999999999995
# Pch_{113_STORAGE_1,1} 0.036524999999999995
# Pch_{114_STORAGE_1,1} 0.036524999999999995
# Pch_{115_STORAGE_1,1} 0.036524999999999995
# Pch_{116_STORAGE_1,1} 0.036524999999999995
# Pch_{117_STORAGE_1,1} 0.036524999999999995
# Pch_{118_STORAGE_1,1} 0.036524999999999995
# Pch_{119_STORAGE_1,1} 0.036524999999999995
# Pch_{120_STORAGE_1,1} 0.036524999999999995
# Pch_{121_STORAGE_1,1} 0.036524999999999995
# Pch_{122_STORAGE_1,1} 0.036524999999999995
# Pch_{123_STORAGE_1,1} 0.036524999999999995
# Pch_{124_STORAGE_1,1} 0.036524999999999995
# Pdis_{101_STORAGE_1,1} 0.65745
# Pdis_{102_STORAGE_1,1} 0.65745
# Pdis_{103_STORAGE_1,1} 0.65745
# Pdis_{104_STORAGE_1,1} 0.65745
# Pdis_{105_STORAGE_1,1} 0.65745
# Pdis_{106_STORAGE_1,1} 0.65745
# Pdis_{107_STORAGE_1,1} 0.65745
# Pdis_{108_STORAGE_1,1} 0.65745
# Pdis_{109_STORAGE_1,1} 0.65745
# Pdis_{110_STORAGE_1,1} 0.65745
# Pdis_{111_STORAGE_1,1} 0.65745
# Pdis_{112_STORAGE_1,1} 0.65745
# Pdis_{113_STORAGE_1,1} 0.65745
# Pdis_{114_STORAGE_1,1} 0.65745
# Pdis_{115_STORAGE_1,1} 0.65745
# Pdis_{116_STORAGE_1,1} 0.65745
# Pdis_{117_STORAGE_1,1} 0.65745
# Pdis_{118_STORAGE_1,1} 0.65745
# Pdis_{119_STORAGE_1,1} 0.65745
# Pdis_{120_STORAGE_1,1} 0.65745
# Pdis_{121_STORAGE_1,1} 0.65745
# Pdis_{122_STORAGE_1,1} 0.65745
# Pdis_{123_STORAGE_1,1} 0.65745
# Pdis_{124_STORAGE_1,1} 0.65745
# Pch_{101_STORAGE_1,2} 0.036524999999999995
# Pch_{102_STORAGE_1,2} 0.036524999999999995
# Pch_{103_STORAGE_1,2} 0.036524999999999995
# Pch_{104_STORAGE_1,2} 0.036524999999999995
# Pch_{105_STORAGE_1,2} 0.036524999999999995
# Pch_{106_STORAGE_1,2} 0.036524999999999995
# Pch_{107_STORAGE_1,2} 0.036524999999999995
# Pch_{108_STORAGE_1,2} 0.036524999999999995
# Pch_{109_STORAGE_1,2} 0.036524999999999995
# Pch_{110_STORAGE_1,2} 0.036524999999999995
# Pch_{111_STORAGE_1,2} 0.036524999999999995
# Pch_{112_STORAGE_1,2} 0.036524999999999995
# Pch_{113_STORAGE_1,2} 0.036524999999999995
# Pch_{114_STORAGE_1,2} 0.036524999999999995
# Pch_{115_STORAGE_1,2} 0.036524999999999995
# Pch_{116_STORAGE_1,2} 0.036524999999999995
# Pch_{117_STORAGE_1,2} 0.036524999999999995
# Pch_{118_STORAGE_1,2} 0.036524999999999995
# Pch_{119_STORAGE_1,2} 0.036524999999999995
# Pch_{120_STORAGE_1,2} 0.036524999999999995
# Pch_{121_STORAGE_1,2} 0.036524999999999995
# Pch_{122_STORAGE_1,2} 0.036524999999999995
# Pch_{123_STORAGE_1,2} 0.036524999999999995
# Pch_{124_STORAGE_1,2} 0.036524999999999995
# Pdis_{101_STORAGE_1,2} 0.65745
# Pdis_{102_STORAGE_1,2} 0.65745
# Pdis_{103_STORAGE_1,2} 0.65745
# Pdis_{104_STORAGE_1,2} 0.65745
# Pdis_{105_STORAGE_1,2} 0.65745
# Pdis_{106_STORAGE_1,2} 0.65745
# Pdis_{107_STORAGE_1,2} 0.65745
# Pdis_{108_STORAGE_1,2} 0.65745
# Pdis_{109_STORAGE_1,2} 0.65745
# Pdis_{110_STORAGE_1,2} 0.65745
# Pdis_{111_STORAGE_1,2} 0.65745
# Pdis_{112_STORAGE_1,2} 0.65745
# Pdis_{113_STORAGE_1,2} 0.65745
# Pdis_{114_STORAGE_1,2} 0.65745
# Pdis_{115_STORAGE_1,2} 0.65745
# Pdis_{116_STORAGE_1,2} 0.65745
# Pdis_{117_STORAGE_1,2} 0.65745
# Pdis_{118_STORAGE_1,2} 0.65745
# Pdis_{119_STORAGE_1,2} 0.65745
# Pdis_{120_STORAGE_1,2} 0.65745
# Pdis_{121_STORAGE_1,2} 0.65745
# Pdis_{122_STORAGE_1,2} 0.65745
# Pdis_{123_STORAGE_1,2} 0.65745
# Pdis_{124_STORAGE_1,2} 0.65745
# Pch_{101_STORAGE_1,3} 0.036524999999999995
# Pch_{102_STORAGE_1,3} 0.036524999999999995
# Pch_{103_STORAGE_1,3} 0.036524999999999995
# Pch_{104_STORAGE_1,3} 0.036524999999999995
# Pch_{105_STORAGE_1,3} 0.036524999999999995
# Pch_{106_STORAGE_1,3} 0.036524999999999995
# Pch_{107_STORAGE_1,3} 0.036524999999999995
# Pch_{108_STORAGE_1,3} 0.036524999999999995
# Pch_{109_STORAGE_1,3} 0.036524999999999995
# Pch_{110_STORAGE_1,3} 0.036524999999999995
# Pch_{111_STORAGE_1,3} 0.036524999999999995
# Pch_{112_STORAGE_1,3} 0.036524999999999995
# Pch_{113_STORAGE_1,3} 0.036524999999999995
# Pch_{114_STORAGE_1,3} 0.036524999999999995
# Pch_{115_STORAGE_1,3} 0.036524999999999995
# Pch_{116_STORAGE_1,3} 0.036524999999999995
# Pch_{117_STORAGE_1,3} 0.036524999999999995
# Pch_{118_STORAGE_1,3} 0.036524999999999995
# Pch_{119_STORAGE_1,3} 0.036524999999999995
# Pch_{120_STORAGE_1,3} 0.036524999999999995
# Pch_{121_STORAGE_1,3} 0.036524999999999995
# Pch_{122_STORAGE_1,3} 0.036524999999999995
# Pch_{123_STORAGE_1,3} 0.036524999999999995
# Pch_{124_STORAGE_1,3} 0.036524999999999995
# Pdis_{101_STORAGE_1,3} 0.65745
# Pdis_{102_STORAGE_1,3} 0.65745
# Pdis_{103_STORAGE_1,3} 0.65745
# Pdis_{104_STORAGE_1,3} 0.65745
# Pdis_{105_STORAGE_1,3} 0.65745
# Pdis_{106_STORAGE_1,3} 0.65745
# Pdis_{107_STORAGE_1,3} 0.65745
# Pdis_{108_STORAGE_1,3} 0.65745
# Pdis_{109_STORAGE_1,3} 0.65745
# Pdis_{110_STORAGE_1,3} 0.65745
# Pdis_{111_STORAGE_1,3} 0.65745
# Pdis_{112_STORAGE_1,3} 0.65745
# Pdis_{113_STORAGE_1,3} 0.65745
# Pdis_{114_STORAGE_1,3} 0.65745
# Pdis_{115_STORAGE_1,3} 0.65745
# Pdis_{116_STORAGE_1,3} 0.65745
# Pdis_{117_STORAGE_1,3} 0.65745
# Pdis_{118_STORAGE_1,3} 0.65745
# Pdis_{119_STORAGE_1,3} 0.65745
# Pdis_{120_STORAGE_1,3} 0.65745
# Pdis_{121_STORAGE_1,3} 0.65745
# Pdis_{122_STORAGE_1,3} 0.65745
# Pdis_{123_STORAGE_1,3} 0.65745
# Pdis_{124_STORAGE_1,3} 0.65745
# Pch_{101_STORAGE_1,4} 0.036524999999999995
# Pch_{102_STORAGE_1,4} 0.036524999999999995
# Pch_{103_STORAGE_1,4} 0.036524999999999995
# Pch_{104_STORAGE_1,4} 0.036524999999999995
# Pch_{105_STORAGE_1,4} 0.036524999999999995
# Pch_{106_STORAGE_1,4} 0.036524999999999995
# Pch_{107_STORAGE_1,4} 0.036524999999999995
# Pch_{108_STORAGE_1,4} 0.036524999999999995
# Pch_{109_STORAGE_1,4} 0.036524999999999995
# Pch_{110_STORAGE_1,4} 0.036524999999999995
# Pch_{111_STORAGE_1,4} 0.036524999999999995
# Pch_{112_STORAGE_1,4} 0.036524999999999995
# Pch_{113_STORAGE_1,4} 0.036524999999999995
# Pch_{114_STORAGE_1,4} 0.036524999999999995
# Pch_{115_STORAGE_1,4} 0.036524999999999995
# Pch_{116_STORAGE_1,4} 0.036524999999999995
# Pch_{117_STORAGE_1,4} 0.036524999999999995
# Pch_{118_STORAGE_1,4} 0.036524999999999995
# Pch_{119_STORAGE_1,4} 0.036524999999999995
# Pch_{120_STORAGE_1,4} 0.036524999999999995
# Pch_{121_STORAGE_1,4} 0.036524999999999995
# Pch_{122_STORAGE_1,4} 0.036524999999999995
# Pch_{123_STORAGE_1,4} 0.036524999999999995
# Pch_{124_STORAGE_1,4} 0.036524999999999995
# Pdis_{101_STORAGE_1,4} 0.65745
# Pdis_{102_STORAGE_1,4} 0.65745
# Pdis_{103_STORAGE_1,4} 0.65745
# Pdis_{104_STORAGE_1,4} 0.65745
# Pdis_{105_STORAGE_1,4} 0.65745
# Pdis_{106_STORAGE_1,4} 0.65745
# Pdis_{107_STORAGE_1,4} 0.65745
# Pdis_{108_STORAGE_1,4} 0.65745
# Pdis_{109_STORAGE_1,4} 0.65745
# Pdis_{110_STORAGE_1,4} 0.65745
# Pdis_{111_STORAGE_1,4} 0.65745
# Pdis_{112_STORAGE_1,4} 0.65745
# Pdis_{113_STORAGE_1,4} 0.65745
# Pdis_{114_STORAGE_1,4} 0.65745
# Pdis_{115_STORAGE_1,4} 0.65745
# Pdis_{116_STORAGE_1,4} 0.65745
# Pdis_{117_STORAGE_1,4} 0.65745
# Pdis_{118_STORAGE_1,4} 0.65745
# Pdis_{119_STORAGE_1,4} 0.65745
# Pdis_{120_STORAGE_1,4} 0.65745
# Pdis_{121_STORAGE_1,4} 0.65745
# Pdis_{122_STORAGE_1,4} 0.65745
# Pdis_{123_STORAGE_1,4} 0.65745
# Pdis_{124_STORAGE_1,4} 0.65745
# Pch_{101_STORAGE_1,5} 0.036524999999999995
# Pch_{102_STORAGE_1,5} 0.036524999999999995
# Pch_{103_STORAGE_1,5} 0.036524999999999995
# Pch_{104_STORAGE_1,5} 0.036524999999999995
# Pch_{105_STORAGE_1,5} 0.036524999999999995
# Pch_{106_STORAGE_1,5} 0.036524999999999995
# Pch_{107_STORAGE_1,5} 0.036524999999999995
# Pch_{108_STORAGE_1,5} 0.036524999999999995
# Pch_{109_STORAGE_1,5} 0.036524999999999995
# Pch_{110_STORAGE_1,5} 0.036524999999999995
# Pch_{111_STORAGE_1,5} 0.036524999999999995
# Pch_{112_STORAGE_1,5} 0.036524999999999995
# Pch_{113_STORAGE_1,5} 0.036524999999999995
# Pch_{114_STORAGE_1,5} 0.036524999999999995
# Pch_{115_STORAGE_1,5} 0.036524999999999995
# Pch_{116_STORAGE_1,5} 0.036524999999999995
# Pch_{117_STORAGE_1,5} 0.036524999999999995
# Pch_{118_STORAGE_1,5} 0.036524999999999995
# Pch_{119_STORAGE_1,5} 0.036524999999999995
# Pch_{120_STORAGE_1,5} 0.036524999999999995
# Pch_{121_STORAGE_1,5} 0.036524999999999995
# Pch_{122_STORAGE_1,5} 0.036524999999999995
# Pch_{123_STORAGE_1,5} 0.036524999999999995
# Pch_{124_STORAGE_1,5} 0.036524999999999995
# Pdis_{101_STORAGE_1,5} 0.65745
# Pdis_{102_STORAGE_1,5} 0.65745
# Pdis_{103_STORAGE_1,5} 0.65745
# Pdis_{104_STORAGE_1,5} 0.65745
# Pdis_{105_STORAGE_1,5} 0.65745
# Pdis_{106_STORAGE_1,5} 0.65745
# Pdis_{107_STORAGE_1,5} 0.65745
# Pdis_{108_STORAGE_1,5} 0.65745
# Pdis_{109_STORAGE_1,5} 0.65745
# Pdis_{110_STORAGE_1,5} 0.65745
# Pdis_{111_STORAGE_1,5} 0.65745
# Pdis_{112_STORAGE_1,5} 0.65745
# Pdis_{113_STORAGE_1,5} 0.65745
# Pdis_{114_STORAGE_1,5} 0.65745
# Pdis_{115_STORAGE_1,5} 0.65745
# Pdis_{116_STORAGE_1,5} 0.65745
# Pdis_{117_STORAGE_1,5} 0.65745
# Pdis_{118_STORAGE_1,5} 0.65745
# Pdis_{119_STORAGE_1,5} 0.65745
# Pdis_{120_STORAGE_1,5} 0.65745
# Pdis_{121_STORAGE_1,5} 0.65745
# Pdis_{122_STORAGE_1,5} 0.65745
# Pdis_{123_STORAGE_1,5} 0.65745
# Pdis_{124_STORAGE_1,5} 0.65745
# Pch_{101_STORAGE_1,6} 0.036524999999999995
# Pch_{102_STORAGE_1,6} 0.036524999999999995
# Pch_{103_STORAGE_1,6} 0.036524999999999995
# Pch_{104_STORAGE_1,6} 0.036524999999999995
# Pch_{105_STORAGE_1,6} 0.036524999999999995
# Pch_{106_STORAGE_1,6} 0.036524999999999995
# Pch_{107_STORAGE_1,6} 0.036524999999999995
# Pch_{108_STORAGE_1,6} 0.036524999999999995
# Pch_{109_STORAGE_1,6} 0.036524999999999995
# Pch_{110_STORAGE_1,6} 0.036524999999999995
# Pch_{111_STORAGE_1,6} 0.036524999999999995
# Pch_{112_STORAGE_1,6} 0.036524999999999995
# Pch_{113_STORAGE_1,6} 0.036524999999999995
# Pch_{114_STORAGE_1,6} 0.036524999999999995
# Pch_{115_STORAGE_1,6} 0.036524999999999995
# Pch_{116_STORAGE_1,6} 0.036524999999999995
# Pch_{117_STORAGE_1,6} 0.036524999999999995
# Pch_{118_STORAGE_1,6} 0.036524999999999995
# Pch_{119_STORAGE_1,6} 0.036524999999999995
# Pch_{120_STORAGE_1,6} 0.036524999999999995
# Pch_{121_STORAGE_1,6} 0.036524999999999995
# Pch_{122_STORAGE_1,6} 0.036524999999999995
# Pch_{123_STORAGE_1,6} 0.036524999999999995
# Pch_{124_STORAGE_1,6} 0.036524999999999995
# Pdis_{101_STORAGE_1,6} 0.65745
# Pdis_{102_STORAGE_1,6} 0.65745
# Pdis_{103_STORAGE_1,6} 0.65745
# Pdis_{104_STORAGE_1,6} 0.65745
# Pdis_{105_STORAGE_1,6} 0.65745
# Pdis_{106_STORAGE_1,6} 0.65745
# Pdis_{107_STORAGE_1,6} 0.65745
# Pdis_{108_STORAGE_1,6} 0.65745
# Pdis_{109_STORAGE_1,6} 0.65745
# Pdis_{110_STORAGE_1,6} 0.65745
# Pdis_{111_STORAGE_1,6} 0.65745
# Pdis_{112_STORAGE_1,6} 0.65745
# Pdis_{113_STORAGE_1,6} 0.65745
# Pdis_{114_STORAGE_1,6} 0.65745
# Pdis_{115_STORAGE_1,6} 0.65745
# Pdis_{116_STORAGE_1,6} 0.65745
# Pdis_{117_STORAGE_1,6} 0.65745
# Pdis_{118_STORAGE_1,6} 0.65745
# Pdis_{119_STORAGE_1,6} 0.65745
# Pdis_{120_STORAGE_1,6} 0.65745
# Pdis_{121_STORAGE_1,6} 0.65745
# Pdis_{122_STORAGE_1,6} 0.65745
# Pdis_{123_STORAGE_1,6} 0.65745
# Pdis_{124_STORAGE_1,6} 0.65745
# Pch_{101_STORAGE_1,7} 0.036524999999999995
# Pch_{102_STORAGE_1,7} 0.036524999999999995
# Pch_{103_STORAGE_1,7} 0.036524999999999995
# Pch_{104_STORAGE_1,7} 0.036524999999999995
# Pch_{105_STORAGE_1,7} 0.036524999999999995
# Pch_{106_STORAGE_1,7} 0.036524999999999995
# Pch_{107_STORAGE_1,7} 0.036524999999999995
# Pch_{108_STORAGE_1,7} 0.036524999999999995
# Pch_{109_STORAGE_1,7} 0.036524999999999995
# Pch_{110_STORAGE_1,7} 0.036524999999999995
# Pch_{111_STORAGE_1,7} 0.036524999999999995
# Pch_{112_STORAGE_1,7} 0.036524999999999995
# Pch_{113_STORAGE_1,7} 0.036524999999999995
# Pch_{114_STORAGE_1,7} 0.036524999999999995
# Pch_{115_STORAGE_1,7} 0.036524999999999995
# Pch_{116_STORAGE_1,7} 0.036524999999999995
# Pch_{117_STORAGE_1,7} 0.036524999999999995
# Pch_{118_STORAGE_1,7} 0.036524999999999995
# Pch_{119_STORAGE_1,7} 0.036524999999999995
# Pch_{120_STORAGE_1,7} 0.036524999999999995
# Pch_{121_STORAGE_1,7} 0.036524999999999995
# Pch_{122_STORAGE_1,7} 0.036524999999999995
# Pch_{123_STORAGE_1,7} 0.036524999999999995
# Pch_{124_STORAGE_1,7} 0.036524999999999995
# Pdis_{101_STORAGE_1,7} 0.65745
# Pdis_{102_STORAGE_1,7} 0.65745
# Pdis_{103_STORAGE_1,7} 0.65745
# Pdis_{104_STORAGE_1,7} 0.65745
# Pdis_{105_STORAGE_1,7} 0.65745
# Pdis_{106_STORAGE_1,7} 0.65745
# Pdis_{107_STORAGE_1,7} 0.65745
# Pdis_{108_STORAGE_1,7} 0.65745
# Pdis_{109_STORAGE_1,7} 0.65745
# Pdis_{110_STORAGE_1,7} 0.65745
# Pdis_{111_STORAGE_1,7} 0.65745
# Pdis_{112_STORAGE_1,7} 0.65745
# Pdis_{113_STORAGE_1,7} 0.65745
# Pdis_{114_STORAGE_1,7} 0.65745
# Pdis_{115_STORAGE_1,7} 0.65745
# Pdis_{116_STORAGE_1,7} 0.65745
# Pdis_{117_STORAGE_1,7} 0.65745
# Pdis_{118_STORAGE_1,7} 0.65745
# Pdis_{119_STORAGE_1,7} 0.65745
# Pdis_{120_STORAGE_1,7} 0.65745
# Pdis_{121_STORAGE_1,7} 0.65745
# Pdis_{122_STORAGE_1,7} 0.65745
# Pdis_{123_STORAGE_1,7} 0.65745
# Pdis_{124_STORAGE_1,7} 0.65745
# Pch_{101_STORAGE_1,8} 0.036524999999999995
# Pch_{102_STORAGE_1,8} 0.036524999999999995
# Pch_{103_STORAGE_1,8} 0.036524999999999995
# Pch_{104_STORAGE_1,8} 0.036524999999999995
# Pch_{105_STORAGE_1,8} 0.036524999999999995
# Pch_{106_STORAGE_1,8} 0.036524999999999995
# Pch_{107_STORAGE_1,8} 0.036524999999999995
# Pch_{108_STORAGE_1,8} 0.036524999999999995
# Pch_{109_STORAGE_1,8} 0.036524999999999995
# Pch_{110_STORAGE_1,8} 0.036524999999999995
# Pch_{111_STORAGE_1,8} 0.036524999999999995
# Pch_{112_STORAGE_1,8} 0.036524999999999995
# Pch_{113_STORAGE_1,8} 0.036524999999999995
# Pch_{114_STORAGE_1,8} 0.036524999999999995
# Pch_{115_STORAGE_1,8} 0.036524999999999995
# Pch_{116_STORAGE_1,8} 0.036524999999999995
# Pch_{117_STORAGE_1,8} 0.036524999999999995
# Pch_{118_STORAGE_1,8} 0.036524999999999995
# Pch_{119_STORAGE_1,8} 0.036524999999999995
# Pch_{120_STORAGE_1,8} 0.036524999999999995
# Pch_{121_STORAGE_1,8} 0.036524999999999995
# Pch_{122_STORAGE_1,8} 0.036524999999999995
# Pch_{123_STORAGE_1,8} 0.036524999999999995
# Pch_{124_STORAGE_1,8} 0.036524999999999995
# Pdis_{101_STORAGE_1,8} 0.65745
# Pdis_{102_STORAGE_1,8} 0.65745
# Pdis_{103_STORAGE_1,8} 0.65745
# Pdis_{104_STORAGE_1,8} 0.65745
# Pdis_{105_STORAGE_1,8} 0.65745
# Pdis_{106_STORAGE_1,8} 0.65745
# Pdis_{107_STORAGE_1,8} 0.65745
# Pdis_{108_STORAGE_1,8} 0.65745
# Pdis_{109_STORAGE_1,8} 0.65745
# Pdis_{110_STORAGE_1,8} 0.65745
# Pdis_{111_STORAGE_1,8} 0.65745
# Pdis_{112_STORAGE_1,8} 0.65745
# Pdis_{113_STORAGE_1,8} 0.65745
# Pdis_{114_STORAGE_1,8} 0.65745
# Pdis_{115_STORAGE_1,8} 0.65745
# Pdis_{116_STORAGE_1,8} 0.65745
# Pdis_{117_STORAGE_1,8} 0.65745
# Pdis_{118_STORAGE_1,8} 0.65745
# Pdis_{119_STORAGE_1,8} 0.65745
# Pdis_{120_STORAGE_1,8} 0.65745
# Pdis_{121_STORAGE_1,8} 0.65745
# Pdis_{122_STORAGE_1,8} 0.65745
# Pdis_{123_STORAGE_1,8} 0.65745
# Pdis_{124_STORAGE_1,8} 0.65745
# Pch_{101_STORAGE_1,9} 0.036524999999999995
# Pch_{102_STORAGE_1,9} 0.036524999999999995
# Pch_{103_STORAGE_1,9} 0.036524999999999995
# Pch_{104_STORAGE_1,9} 0.036524999999999995
# Pch_{105_STORAGE_1,9} 0.036524999999999995
# Pch_{106_STORAGE_1,9} 0.036524999999999995
# Pch_{107_STORAGE_1,9} 0.036524999999999995
# Pch_{108_STORAGE_1,9} 0.036524999999999995
# Pch_{109_STORAGE_1,9} 0.036524999999999995
# Pch_{110_STORAGE_1,9} 0.036524999999999995
# Pch_{111_STORAGE_1,9} 0.036524999999999995
# Pch_{112_STORAGE_1,9} 0.036524999999999995
# Pch_{113_STORAGE_1,9} 0.036524999999999995
# Pch_{114_STORAGE_1,9} 0.036524999999999995
# Pch_{115_STORAGE_1,9} 0.036524999999999995
# Pch_{116_STORAGE_1,9} 0.036524999999999995
# Pch_{117_STORAGE_1,9} 0.036524999999999995
# Pch_{118_STORAGE_1,9} 0.036524999999999995
# Pch_{119_STORAGE_1,9} 0.036524999999999995
# Pch_{120_STORAGE_1,9} 0.036524999999999995
# Pch_{121_STORAGE_1,9} 0.036524999999999995
# Pch_{122_STORAGE_1,9} 0.036524999999999995
# Pch_{123_STORAGE_1,9} 0.036524999999999995
# Pch_{124_STORAGE_1,9} 0.036524999999999995
# Pdis_{101_STORAGE_1,9} 0.65745
# Pdis_{102_STORAGE_1,9} 0.65745
# Pdis_{103_STORAGE_1,9} 0.65745
# Pdis_{104_STORAGE_1,9} 0.65745
# Pdis_{105_STORAGE_1,9} 0.65745
# Pdis_{106_STORAGE_1,9} 0.65745
# Pdis_{107_STORAGE_1,9} 0.65745
# Pdis_{108_STORAGE_1,9} 0.65745
# Pdis_{109_STORAGE_1,9} 0.65745
# Pdis_{110_STORAGE_1,9} 0.65745
# Pdis_{111_STORAGE_1,9} 0.65745
# Pdis_{112_STORAGE_1,9} 0.65745
# Pdis_{113_STORAGE_1,9} 0.65745
# Pdis_{114_STORAGE_1,9} 0.65745
# Pdis_{115_STORAGE_1,9} 0.65745
# Pdis_{116_STORAGE_1,9} 0.65745
# Pdis_{117_STORAGE_1,9} 0.65745
# Pdis_{118_STORAGE_1,9} 0.65745
# Pdis_{119_STORAGE_1,9} 0.65745
# Pdis_{120_STORAGE_1,9} 0.65745
# Pdis_{121_STORAGE_1,9} 0.65745
# Pdis_{122_STORAGE_1,9} 0.65745
# Pdis_{123_STORAGE_1,9} 0.65745
# Pdis_{124_STORAGE_1,9} 0.65745
# Pch_{101_STORAGE_1,10} 0.036524999999999995
# Pch_{102_STORAGE_1,10} 0.036524999999999995
# Pch_{103_STORAGE_1,10} 0.036524999999999995
# Pch_{104_STORAGE_1,10} 0.036524999999999995
# Pch_{105_STORAGE_1,10} 0.036524999999999995
# Pch_{106_STORAGE_1,10} 0.036524999999999995
# Pch_{107_STORAGE_1,10} 0.036524999999999995
# Pch_{108_STORAGE_1,10} 0.036524999999999995
# Pch_{109_STORAGE_1,10} 0.036524999999999995
# Pch_{110_STORAGE_1,10} 0.036524999999999995
# Pch_{111_STORAGE_1,10} 0.036524999999999995
# Pch_{112_STORAGE_1,10} 0.036524999999999995
# Pch_{113_STORAGE_1,10} 0.036524999999999995
# Pch_{114_STORAGE_1,10} 0.036524999999999995
# Pch_{115_STORAGE_1,10} 0.036524999999999995
# Pch_{116_STORAGE_1,10} 0.036524999999999995
# Pch_{117_STORAGE_1,10} 0.036524999999999995
# Pch_{118_STORAGE_1,10} 0.036524999999999995
# Pch_{119_STORAGE_1,10} 0.036524999999999995
# Pch_{120_STORAGE_1,10} 0.036524999999999995
# Pch_{121_STORAGE_1,10} 0.036524999999999995
# Pch_{122_STORAGE_1,10} 0.036524999999999995
# Pch_{123_STORAGE_1,10} 0.036524999999999995
# Pch_{124_STORAGE_1,10} 0.036524999999999995
# Pdis_{101_STORAGE_1,10} 0.65745
# Pdis_{102_STORAGE_1,10} 0.65745
# Pdis_{103_STORAGE_1,10} 0.65745
# Pdis_{104_STORAGE_1,10} 0.65745
# Pdis_{105_STORAGE_1,10} 0.65745
# Pdis_{106_STORAGE_1,10} 0.65745
# Pdis_{107_STORAGE_1,10} 0.65745
# Pdis_{108_STORAGE_1,10} 0.65745
# Pdis_{109_STORAGE_1,10} 0.65745
# Pdis_{110_STORAGE_1,10} 0.65745
# Pdis_{111_STORAGE_1,10} 0.65745
# Pdis_{112_STORAGE_1,10} 0.65745
# Pdis_{113_STORAGE_1,10} 0.65745
# Pdis_{114_STORAGE_1,10} 0.65745
# Pdis_{115_STORAGE_1,10} 0.65745
# Pdis_{116_STORAGE_1,10} 0.65745
# Pdis_{117_STORAGE_1,10} 0.65745
# Pdis_{118_STORAGE_1,10} 0.65745
# Pdis_{119_STORAGE_1,10} 0.65745
# Pdis_{120_STORAGE_1,10} 0.65745
# Pdis_{121_STORAGE_1,10} 0.65745
# Pdis_{122_STORAGE_1,10} 0.65745
# Pdis_{123_STORAGE_1,10} 0.65745
# Pdis_{124_STORAGE_1,10} 0.65745
# Pch_{101_STORAGE_1,11} 0.036524999999999995
# Pch_{102_STORAGE_1,11} 0.036524999999999995
# Pch_{103_STORAGE_1,11} 0.036524999999999995
# Pch_{104_STORAGE_1,11} 0.036524999999999995
# Pch_{105_STORAGE_1,11} 0.036524999999999995
# Pch_{106_STORAGE_1,11} 0.036524999999999995
# Pch_{107_STORAGE_1,11} 0.036524999999999995
# Pch_{108_STORAGE_1,11} 0.036524999999999995
# Pch_{109_STORAGE_1,11} 0.036524999999999995
# Pch_{110_STORAGE_1,11} 0.036524999999999995
# Pch_{111_STORAGE_1,11} 0.036524999999999995
# Pch_{112_STORAGE_1,11} 0.036524999999999995
# Pch_{113_STORAGE_1,11} 0.036524999999999995
# Pch_{114_STORAGE_1,11} 0.036524999999999995
# Pch_{115_STORAGE_1,11} 0.036524999999999995
# Pch_{116_STORAGE_1,11} 0.036524999999999995
# Pch_{117_STORAGE_1,11} 0.036524999999999995
# Pch_{118_STORAGE_1,11} 0.036524999999999995
# Pch_{119_STORAGE_1,11} 0.036524999999999995
# Pch_{120_STORAGE_1,11} 0.036524999999999995
# Pch_{121_STORAGE_1,11} 0.036524999999999995
# Pch_{122_STORAGE_1,11} 0.036524999999999995
# Pch_{123_STORAGE_1,11} 0.036524999999999995
# Pch_{124_STORAGE_1,11} 0.036524999999999995
# Pdis_{101_STORAGE_1,11} 0.65745
# Pdis_{102_STORAGE_1,11} 0.65745
# Pdis_{103_STORAGE_1,11} 0.65745
# Pdis_{104_STORAGE_1,11} 0.65745
# Pdis_{105_STORAGE_1,11} 0.65745
# Pdis_{106_STORAGE_1,11} 0.65745
# Pdis_{107_STORAGE_1,11} 0.65745
# Pdis_{108_STORAGE_1,11} 0.65745
# Pdis_{109_STORAGE_1,11} 0.65745
# Pdis_{110_STORAGE_1,11} 0.65745
# Pdis_{111_STORAGE_1,11} 0.65745
# Pdis_{112_STORAGE_1,11} 0.65745
# Pdis_{113_STORAGE_1,11} 0.65745
# Pdis_{114_STORAGE_1,11} 0.65745
# Pdis_{115_STORAGE_1,11} 0.65745
# Pdis_{116_STORAGE_1,11} 0.65745
# Pdis_{117_STORAGE_1,11} 0.65745
# Pdis_{118_STORAGE_1,11} 0.65745
# Pdis_{119_STORAGE_1,11} 0.65745
# Pdis_{120_STORAGE_1,11} 0.65745
# Pdis_{121_STORAGE_1,11} 0.65745
# Pdis_{122_STORAGE_1,11} 0.65745
# Pdis_{123_STORAGE_1,11} 0.65745
# Pdis_{124_STORAGE_1,11} 0.65745
# Pch_{101_STORAGE_1,12} 0.036524999999999995
# Pch_{102_STORAGE_1,12} 0.036524999999999995
# Pch_{103_STORAGE_1,12} 0.036524999999999995
# Pch_{104_STORAGE_1,12} 0.036524999999999995
# Pch_{105_STORAGE_1,12} 0.036524999999999995
# Pch_{106_STORAGE_1,12} 0.036524999999999995
# Pch_{107_STORAGE_1,12} 0.036524999999999995
# Pch_{108_STORAGE_1,12} 0.036524999999999995
# Pch_{109_STORAGE_1,12} 0.036524999999999995
# Pch_{110_STORAGE_1,12} 0.036524999999999995
# Pch_{111_STORAGE_1,12} 0.036524999999999995
# Pch_{112_STORAGE_1,12} 0.036524999999999995
# Pch_{113_STORAGE_1,12} 0.036524999999999995
# Pch_{114_STORAGE_1,12} 0.036524999999999995
# Pch_{115_STORAGE_1,12} 0.036524999999999995
# Pch_{116_STORAGE_1,12} 0.036524999999999995
# Pch_{117_STORAGE_1,12} 0.036524999999999995
# Pch_{118_STORAGE_1,12} 0.036524999999999995
# Pch_{119_STORAGE_1,12} 0.036524999999999995
# Pch_{120_STORAGE_1,12} 0.036524999999999995
# Pch_{121_STORAGE_1,12} 0.036524999999999995
# Pch_{122_STORAGE_1,12} 0.036524999999999995
# Pch_{123_STORAGE_1,12} 0.036524999999999995
# Pch_{124_STORAGE_1,12} 0.036524999999999995
# Pdis_{101_STORAGE_1,12} 0.65745
# Pdis_{102_STORAGE_1,12} 0.65745
# Pdis_{103_STORAGE_1,12} 0.65745
# Pdis_{104_STORAGE_1,12} 0.65745
# Pdis_{105_STORAGE_1,12} 0.65745
# Pdis_{106_STORAGE_1,12} 0.65745
# Pdis_{107_STORAGE_1,12} 0.65745
# Pdis_{108_STORAGE_1,12} 0.65745
# Pdis_{109_STORAGE_1,12} 0.65745
# Pdis_{110_STORAGE_1,12} 0.65745
# Pdis_{111_STORAGE_1,12} 0.65745
# Pdis_{112_STORAGE_1,12} 0.65745
# Pdis_{113_STORAGE_1,12} 0.65745
# Pdis_{114_STORAGE_1,12} 0.65745
# Pdis_{115_STORAGE_1,12} 0.65745
# Pdis_{116_STORAGE_1,12} 0.65745
# Pdis_{117_STORAGE_1,12} 0.65745
# Pdis_{118_STORAGE_1,12} 0.65745
# Pdis_{119_STORAGE_1,12} 0.65745
# Pdis_{120_STORAGE_1,12} 0.65745
# Pdis_{121_STORAGE_1,12} 0.65745
# Pdis_{122_STORAGE_1,12} 0.65745
# Pdis_{123_STORAGE_1,12} 0.65745
# Pdis_{124_STORAGE_1,12} 0.65745
# Pch_{101_STORAGE_1,13} 0.036524999999999995
# Pch_{102_STORAGE_1,13} 0.036524999999999995
# Pch_{103_STORAGE_1,13} 0.036524999999999995
# Pch_{104_STORAGE_1,13} 0.036524999999999995
# Pch_{105_STORAGE_1,13} 0.036524999999999995
# Pch_{106_STORAGE_1,13} 0.036524999999999995
# Pch_{107_STORAGE_1,13} 0.036524999999999995
# Pch_{108_STORAGE_1,13} 0.036524999999999995
# Pch_{109_STORAGE_1,13} 0.036524999999999995
# Pch_{110_STORAGE_1,13} 0.036524999999999995
# Pch_{111_STORAGE_1,13} 0.036524999999999995
# Pch_{112_STORAGE_1,13} 0.036524999999999995
# Pch_{113_STORAGE_1,13} 0.036524999999999995
# Pch_{114_STORAGE_1,13} 0.036524999999999995
# Pch_{115_STORAGE_1,13} 0.036524999999999995
# Pch_{116_STORAGE_1,13} 0.036524999999999995
# Pch_{117_STORAGE_1,13} 0.036524999999999995
# Pch_{118_STORAGE_1,13} 0.036524999999999995
# Pch_{119_STORAGE_1,13} 0.036524999999999995
# Pch_{120_STORAGE_1,13} 0.036524999999999995
# Pch_{121_STORAGE_1,13} 0.036524999999999995
# Pch_{122_STORAGE_1,13} 0.036524999999999995
# Pch_{123_STORAGE_1,13} 0.036524999999999995
# Pch_{124_STORAGE_1,13} 0.036524999999999995
# Pdis_{101_STORAGE_1,13} 0.65745
# Pdis_{102_STORAGE_1,13} 0.65745
# Pdis_{103_STORAGE_1,13} 0.65745
# Pdis_{104_STORAGE_1,13} 0.65745
# Pdis_{105_STORAGE_1,13} 0.65745
# Pdis_{106_STORAGE_1,13} 0.65745
# Pdis_{107_STORAGE_1,13} 0.65745
# Pdis_{108_STORAGE_1,13} 0.65745
# Pdis_{109_STORAGE_1,13} 0.65745
# Pdis_{110_STORAGE_1,13} 0.65745
# Pdis_{111_STORAGE_1,13} 0.65745
# Pdis_{112_STORAGE_1,13} 0.65745
# Pdis_{113_STORAGE_1,13} 0.65745
# Pdis_{114_STORAGE_1,13} 0.65745
# Pdis_{115_STORAGE_1,13} 0.65745
# Pdis_{116_STORAGE_1,13} 0.65745
# Pdis_{117_STORAGE_1,13} 0.65745
# Pdis_{118_STORAGE_1,13} 0.65745
# Pdis_{119_STORAGE_1,13} 0.65745
# Pdis_{120_STORAGE_1,13} 0.65745
# Pdis_{121_STORAGE_1,13} 0.65745
# Pdis_{122_STORAGE_1,13} 0.65745
# Pdis_{123_STORAGE_1,13} 0.65745
# Pdis_{124_STORAGE_1,13} 0.65745
# Pch_{101_STORAGE_1,14} 0.036524999999999995
# Pch_{102_STORAGE_1,14} 0.036524999999999995
# Pch_{103_STORAGE_1,14} 0.036524999999999995
# Pch_{104_STORAGE_1,14} 0.036524999999999995
# Pch_{105_STORAGE_1,14} 0.036524999999999995
# Pch_{106_STORAGE_1,14} 0.036524999999999995
# Pch_{107_STORAGE_1,14} 0.036524999999999995
# Pch_{108_STORAGE_1,14} 0.036524999999999995
# Pch_{109_STORAGE_1,14} 0.036524999999999995
# Pch_{110_STORAGE_1,14} 0.036524999999999995
# Pch_{111_STORAGE_1,14} 0.036524999999999995
# Pch_{112_STORAGE_1,14} 0.036524999999999995
# Pch_{113_STORAGE_1,14} 0.036524999999999995
# Pch_{114_STORAGE_1,14} 0.036524999999999995
# Pch_{115_STORAGE_1,14} 0.036524999999999995
# Pch_{116_STORAGE_1,14} 0.036524999999999995
# Pch_{117_STORAGE_1,14} 0.036524999999999995
# Pch_{118_STORAGE_1,14} 0.036524999999999995
# Pch_{119_STORAGE_1,14} 0.036524999999999995
# Pch_{120_STORAGE_1,14} 0.036524999999999995
# Pch_{121_STORAGE_1,14} 0.036524999999999995
# Pch_{122_STORAGE_1,14} 0.036524999999999995
# Pch_{123_STORAGE_1,14} 0.036524999999999995
# Pch_{124_STORAGE_1,14} 0.036524999999999995
# Pdis_{101_STORAGE_1,14} 0.65745
# Pdis_{102_STORAGE_1,14} 0.65745
# Pdis_{103_STORAGE_1,14} 0.65745
# Pdis_{104_STORAGE_1,14} 0.65745
# Pdis_{105_STORAGE_1,14} 0.65745
# Pdis_{106_STORAGE_1,14} 0.65745
# Pdis_{107_STORAGE_1,14} 0.65745
# Pdis_{108_STORAGE_1,14} 0.65745
# Pdis_{109_STORAGE_1,14} 0.65745
# Pdis_{110_STORAGE_1,14} 0.65745
# Pdis_{111_STORAGE_1,14} 0.65745
# Pdis_{112_STORAGE_1,14} 0.65745
# Pdis_{113_STORAGE_1,14} 0.65745
# Pdis_{114_STORAGE_1,14} 0.65745
# Pdis_{115_STORAGE_1,14} 0.65745
# Pdis_{116_STORAGE_1,14} 0.65745
# Pdis_{117_STORAGE_1,14} 0.65745
# Pdis_{118_STORAGE_1,14} 0.65745
# Pdis_{119_STORAGE_1,14} 0.65745
# Pdis_{120_STORAGE_1,14} 0.65745
# Pdis_{121_STORAGE_1,14} 0.65745
# Pdis_{122_STORAGE_1,14} 0.65745
# Pdis_{123_STORAGE_1,14} 0.65745
# Pdis_{124_STORAGE_1,14} 0.65745
# Pch_{101_STORAGE_1,15} 0.036524999999999995
# Pch_{102_STORAGE_1,15} 0.036524999999999995
# Pch_{103_STORAGE_1,15} 0.036524999999999995
# Pch_{104_STORAGE_1,15} 0.036524999999999995
# Pch_{105_STORAGE_1,15} 0.036524999999999995
# Pch_{106_STORAGE_1,15} 0.036524999999999995
# Pch_{107_STORAGE_1,15} 0.036524999999999995
# Pch_{108_STORAGE_1,15} 0.036524999999999995
# Pch_{109_STORAGE_1,15} 0.036524999999999995
# Pch_{110_STORAGE_1,15} 0.036524999999999995
# Pch_{111_STORAGE_1,15} 0.036524999999999995
# Pch_{112_STORAGE_1,15} 0.036524999999999995
# Pch_{113_STORAGE_1,15} 0.036524999999999995
# Pch_{114_STORAGE_1,15} 0.036524999999999995
# Pch_{115_STORAGE_1,15} 0.036524999999999995
# Pch_{116_STORAGE_1,15} 0.036524999999999995
# Pch_{117_STORAGE_1,15} 0.036524999999999995
# Pch_{118_STORAGE_1,15} 0.036524999999999995
# Pch_{119_STORAGE_1,15} 0.036524999999999995
# Pch_{120_STORAGE_1,15} 0.036524999999999995
# Pch_{121_STORAGE_1,15} 0.036524999999999995
# Pch_{122_STORAGE_1,15} 0.036524999999999995
# Pch_{123_STORAGE_1,15} 0.036524999999999995
# Pch_{124_STORAGE_1,15} 0.036524999999999995
# Pdis_{101_STORAGE_1,15} 0.65745
# Pdis_{102_STORAGE_1,15} 0.65745
# Pdis_{103_STORAGE_1,15} 0.65745
# Pdis_{104_STORAGE_1,15} 0.65745
# Pdis_{105_STORAGE_1,15} 0.65745
# Pdis_{106_STORAGE_1,15} 0.65745
# Pdis_{107_STORAGE_1,15} 0.65745
# Pdis_{108_STORAGE_1,15} 0.65745
# Pdis_{109_STORAGE_1,15} 0.65745
# Pdis_{110_STORAGE_1,15} 0.65745
# Pdis_{111_STORAGE_1,15} 0.65745
# Pdis_{112_STORAGE_1,15} 0.65745
# Pdis_{113_STORAGE_1,15} 0.65745
# Pdis_{114_STORAGE_1,15} 0.65745
# Pdis_{115_STORAGE_1,15} 0.65745
# Pdis_{116_STORAGE_1,15} 0.65745
# Pdis_{117_STORAGE_1,15} 0.65745
# Pdis_{118_STORAGE_1,15} 0.65745
# Pdis_{119_STORAGE_1,15} 0.65745
# Pdis_{120_STORAGE_1,15} 0.65745
# Pdis_{121_STORAGE_1,15} 0.65745
# ...
# LOL_{115,7} 73.05
# OL_{115,7} 73.05
# LOL_{116,7} 73.05
# OL_{116,7} 73.05
# LOL_{117,7} 73.05
# OL_{117,7} 73.05
# LOL_{118,7} 73.05
# OL_{118,7} 73.05
# LOL_{119,7} 73.05
# OL_{119,7} 73.05
# LOL_{120,7} 73.05
# OL_{120,7} 73.05
# LOL_{121,7} 73.05
# OL_{121,7} 73.05
# LOL_{122,7} 73.05
# OL_{122,7} 73.05
# LOL_{123,7} 73.05
# OL_{123,7} 73.05
# LOL_{124,7} 73.05
# OL_{124,7} 73.05
# LOL_{101,8} 73.05
# OL_{101,8} 73.05
# LOL_{102,8} 73.05
# OL_{102,8} 73.05
# LOL_{103,8} 73.05
# OL_{103,8} 73.05
# LOL_{104,8} 73.05
# OL_{104,8} 73.05
# LOL_{105,8} 73.05
# OL_{105,8} 73.05
# LOL_{106,8} 73.05
# OL_{106,8} 73.05
# LOL_{107,8} 73.05
# OL_{107,8} 73.05
# LOL_{108,8} 73.05
# OL_{108,8} 73.05
# LOL_{109,8} 73.05
# OL_{109,8} 73.05
# LOL_{110,8} 73.05
# OL_{110,8} 73.05
# LOL_{111,8} 73.05
# OL_{111,8} 73.05
# LOL_{112,8} 73.05
# OL_{112,8} 73.05
# LOL_{113,8} 73.05
# OL_{113,8} 73.05
# LOL_{114,8} 73.05
# OL_{114,8} 73.05
# LOL_{115,8} 73.05
# OL_{115,8} 73.05
# LOL_{116,8} 73.05
# OL_{116,8} 73.05
# LOL_{117,8} 73.05
# OL_{117,8} 73.05
# LOL_{118,8} 73.05
# OL_{118,8} 73.05
# LOL_{119,8} 73.05
# OL_{119,8} 73.05
# LOL_{120,8} 73.05
# OL_{120,8} 73.05
# LOL_{121,8} 73.05
# OL_{121,8} 73.05
# LOL_{122,8} 73.05
# OL_{122,8} 73.05
# LOL_{123,8} 73.05
# OL_{123,8} 73.05
# LOL_{124,8} 73.05
# OL_{124,8} 73.05
# LOL_{101,9} 73.05
# OL_{101,9} 73.05
# LOL_{102,9} 73.05
# OL_{102,9} 73.05
# LOL_{103,9} 73.05
# OL_{103,9} 73.05
# LOL_{104,9} 73.05
# OL_{104,9} 73.05
# LOL_{105,9} 73.05
# OL_{105,9} 73.05
# LOL_{106,9} 73.05
# OL_{106,9} 73.05
# LOL_{107,9} 73.05
# OL_{107,9} 73.05
# LOL_{108,9} 73.05
# OL_{108,9} 73.05
# LOL_{109,9} 73.05
# OL_{109,9} 73.05
# LOL_{110,9} 73.05
# OL_{110,9} 73.05
# LOL_{111,9} 73.05
# OL_{111,9} 73.05
# LOL_{112,9} 73.05
# OL_{112,9} 73.05
# LOL_{113,9} 73.05
# OL_{113,9} 73.05
# LOL_{114,9} 73.05
# OL_{114,9} 73.05
# LOL_{115,9} 73.05
# OL_{115,9} 73.05
# LOL_{116,9} 73.05
# OL_{116,9} 73.05
# LOL_{117,9} 73.05
# OL_{117,9} 73.05
# LOL_{118,9} 73.05
# OL_{118,9} 73.05
# LOL_{119,9} 73.05
# OL_{119,9} 73.05
# LOL_{120,9} 73.05
# OL_{120,9} 73.05
# LOL_{121,9} 73.05
# OL_{121,9} 73.05
# LOL_{122,9} 73.05
# OL_{122,9} 73.05
# LOL_{123,9} 73.05
# OL_{123,9} 73.05
# LOL_{124,9} 73.05
# OL_{124,9} 73.05
# LOL_{101,10} 73.05
# OL_{101,10} 73.05
# LOL_{102,10} 73.05
# OL_{102,10} 73.05
# LOL_{103,10} 73.05
# OL_{103,10} 73.05
# LOL_{104,10} 73.05
# OL_{104,10} 73.05
# LOL_{105,10} 73.05
# OL_{105,10} 73.05
# LOL_{106,10} 73.05
# OL_{106,10} 73.05
# LOL_{107,10} 73.05
# OL_{107,10} 73.05
# LOL_{108,10} 73.05
# OL_{108,10} 73.05
# LOL_{109,10} 73.05
# OL_{109,10} 73.05
# LOL_{110,10} 73.05
# OL_{110,10} 73.05
# LOL_{111,10} 73.05
# OL_{111,10} 73.05
# LOL_{112,10} 73.05
# OL_{112,10} 73.05
# LOL_{113,10} 73.05
# OL_{113,10} 73.05
# LOL_{114,10} 73.05
# OL_{114,10} 73.05
# LOL_{115,10} 73.05
# OL_{115,10} 73.05
# LOL_{116,10} 73.05
# OL_{116,10} 73.05
# LOL_{117,10} 73.05
# OL_{117,10} 73.05
# LOL_{118,10} 73.05
# OL_{118,10} 73.05
# LOL_{119,10} 73.05
# OL_{119,10} 73.05
# LOL_{120,10} 73.05
# OL_{120,10} 73.05
# LOL_{121,10} 73.05
# OL_{121,10} 73.05
# LOL_{122,10} 73.05
# OL_{122,10} 73.05
# LOL_{123,10} 73.05
# OL_{123,10} 73.05
# LOL_{124,10} 73.05
# OL_{124,10} 73.05
# LOL_{101,11} 73.05
# OL_{101,11} 73.05
# LOL_{102,11} 73.05
# OL_{102,11} 73.05
# LOL_{103,11} 73.05
# OL_{103,11} 73.05
# LOL_{104,11} 73.05
# OL_{104,11} 73.05
# LOL_{105,11} 73.05
# OL_{105,11} 73.05
# LOL_{106,11} 73.05
# OL_{106,11} 73.05
# LOL_{107,11} 73.05
# OL_{107,11} 73.05
# LOL_{108,11} 73.05
# OL_{108,11} 73.05
# LOL_{109,11} 73.05
# OL_{109,11} 73.05
# LOL_{110,11} 73.05
# OL_{110,11} 73.05
# LOL_{111,11} 73.05
# OL_{111,11} 73.05
# LOL_{112,11} 73.05
# OL_{112,11} 73.05
# LOL_{113,11} 73.05
# OL_{113,11} 73.05
# LOL_{114,11} 73.05
# OL_{114,11} 73.05
# LOL_{115,11} 73.05
# OL_{115,11} 73.05
# LOL_{116,11} 73.05
# OL_{116,11} 73.05
# LOL_{117,11} 73.05
# OL_{117,11} 73.05
# LOL_{118,11} 73.05
# OL_{118,11} 73.05
# LOL_{119,11} 73.05
# OL_{119,11} 73.05
# LOL_{120,11} 73.05
# OL_{120,11} 73.05
# LOL_{121,11} 73.05
# OL_{121,11} 73.05
# LOL_{122,11} 73.05
# OL_{122,11} 73.05
# LOL_{123,11} 73.05
# OL_{123,11} 73.05
# LOL_{124,11} 73.05
# OL_{124,11} 73.05
# LOL_{101,12} 73.05
# OL_{101,12} 73.05
# LOL_{102,12} 73.05
# OL_{102,12} 73.05
# LOL_{103,12} 73.05
# OL_{103,12} 73.05
# LOL_{104,12} 73.05
# OL_{104,12} 73.05
# LOL_{105,12} 73.05
# OL_{105,12} 73.05
# LOL_{106,12} 73.05
# OL_{106,12} 73.05
# LOL_{107,12} 73.05
# OL_{107,12} 73.05
# LOL_{108,12} 73.05
# OL_{108,12} 73.05
# LOL_{109,12} 73.05
# OL_{109,12} 73.05
# LOL_{110,12} 73.05
# OL_{110,12} 73.05
# LOL_{111,12} 73.05
# OL_{111,12} 73.05
# LOL_{112,12} 73.05
# OL_{112,12} 73.05
# LOL_{113,12} 73.05
# OL_{113,12} 73.05
# LOL_{114,12} 73.05
# OL_{114,12} 73.05
# LOL_{115,12} 73.05
# OL_{115,12} 73.05
# LOL_{116,12} 73.05
# OL_{116,12} 73.05
# LOL_{117,12} 73.05
# OL_{117,12} 73.05
# LOL_{118,12} 73.05
# OL_{118,12} 73.05
# LOL_{119,12} 73.05
# OL_{119,12} 73.05
# LOL_{120,12} 73.05
# OL_{120,12} 73.05
# LOL_{121,12} 73.05
# OL_{121,12} 73.05
# LOL_{122,12} 73.05
# OL_{122,12} 73.05
# LOL_{123,12} 73.05
# OL_{123,12} 73.05
# LOL_{124,12} 73.05
# OL_{124,12} 73.05
# LOL_{101,13} 73.05
# OL_{101,13} 73.05
# LOL_{102,13} 73.05
# OL_{102,13} 73.05
# LOL_{103,13} 73.05
# OL_{103,13} 73.05
# LOL_{104,13} 73.05
# OL_{104,13} 73.05
# LOL_{105,13} 73.05
# OL_{105,13} 73.05
# LOL_{106,13} 73.05
# OL_{106,13} 73.05
# LOL_{107,13} 73.05
# OL_{107,13} 73.05
# LOL_{108,13} 73.05
# OL_{108,13} 73.05
# LOL_{109,13} 73.05
# OL_{109,13} 73.05
# LOL_{110,13} 73.05
# OL_{110,13} 73.05
# LOL_{111,13} 73.05
# OL_{111,13} 73.05
# LOL_{112,13} 73.05
# OL_{112,13} 73.05
# LOL_{113,13} 73.05
# OL_{113,13} 73.05
# LOL_{114,13} 73.05
# OL_{114,13} 73.05
# LOL_{115,13} 73.05
# OL_{115,13} 73.05
# LOL_{116,13} 73.05
# OL_{116,13} 73.05
# LOL_{117,13} 73.05
# OL_{117,13} 73.05
# LOL_{118,13} 73.05
# OL_{118,13} 73.05
# LOL_{119,13} 73.05
# OL_{119,13} 73.05
# LOL_{120,13} 73.05
# OL_{120,13} 73.05
# LOL_{121,13} 73.05
# OL_{121,13} 73.05
# LOL_{122,13} 73.05
# OL_{122,13} 73.05
# LOL_{123,13} 73.05
# OL_{123,13} 73.05
# LOL_{124,13} 73.05
# OL_{124,13} 73.05
# LOL_{101,14} 73.05
# OL_{101,14} 73.05
# LOL_{102,14} 73.05
# OL_{102,14} 73.05
# LOL_{103,14} 73.05
# OL_{103,14} 73.05
# LOL_{104,14} 73.05
# OL_{104,14} 73.05
# LOL_{105,14} 73.05
# OL_{105,14} 73.05
# LOL_{106,14} 73.05
# OL_{106,14} 73.05
# LOL_{107,14} 73.05
# OL_{107,14} 73.05
# LOL_{108,14} 73.05
# OL_{108,14} 73.05
# LOL_{109,14} 73.05
# OL_{109,14} 73.05
# LOL_{110,14} 73.05
# OL_{110,14} 73.05
# LOL_{111,14} 73.05
# OL_{111,14} 73.05
# LOL_{112,14} 73.05
# OL_{112,14} 73.05
# LOL_{113,14} 73.05
# OL_{113,14} 73.05
# LOL_{114,14} 73.05
# OL_{114,14} 73.05
# LOL_{115,14} 73.05
# OL_{115,14} 73.05
# LOL_{116,14} 73.05
# OL_{116,14} 73.05
# LOL_{117,14} 73.05
# OL_{117,14} 73.05
# LOL_{118,14} 73.05
# OL_{118,14} 73.05
# LOL_{119,14} 73.05
# OL_{119,14} 73.05
# LOL_{120,14} 73.05
# OL_{120,14} 73.05
# LOL_{121,14} 73.05
# OL_{121,14} 73.05
# LOL_{122,14} 73.05
# OL_{122,14} 73.05
# LOL_{123,14} 73.05
# OL_{123,14} 73.05
# LOL_{124,14} 73.05
# OL_{124,14} 73.05
# LOL_{101,15} 73.05
# OL_{101,15} 73.05
# LOL_{102,15} 73.05
# OL_{102,15} 73.05
# LOL_{103,15} 73.05
# OL_{103,15} 73.05
# LOL_{104,15} 73.05
# OL_{104,15} 73.05
# LOL_{105,15} 73.05
# OL_{105,15} 73.05
# LOL_{106,15} 73.05
# OL_{106,15} 73.05
# LOL_{107,15} 73.05
# OL_{107,15} 73.05
# LOL_{108,15} 73.05
# OL_{108,15} 73.05
# LOL_{109,15} 73.05
# OL_{109,15} 73.05
# LOL_{110,15} 73.05
# OL_{110,15} 73.05
# LOL_{111,15} 73.05
# OL_{111,15} 73.05
# LOL_{112,15} 73.05
# OL_{112,15} 73.05
# LOL_{113,15} 73.05
# OL_{113,15} 73.05
# LOL_{114,15} 73.05
# OL_{114,15} 73.05
# LOL_{115,15} 73.05
# OL_{115,15} 73.05
# LOL_{116,15} 73.05
# OL_{116,15} 73.05
# LOL_{117,15} 73.05
# OL_{117,15} 73.05
# LOL_{118,15} 73.05
# OL_{118,15} 73.05
# LOL_{119,15} 73.05
# OL_{119,15} 73.05
# LOL_{120,15} 73.05
# OL_{120,15} 73.05
# LOL_{121,15} 73.05
# OL_{121,15} 73.05
# LOL_{122,15} 73.05
# OL_{122,15} 73.05
# LOL_{123,15} 73.05
# OL_{123,15} 73.05
# LOL_{124,15} 73.05
# OL_{124,15} 73.05
# LOL_{101,16} 73.05
# OL_{101,16} 73.05
# LOL_{102,16} 73.05
# OL_{102,16} 73.05
# LOL_{103,16} 73.05
# OL_{103,16} 73.05
# LOL_{104,16} 73.05
# OL_{104,16} 73.05
# LOL_{105,16} 73.05
# OL_{105,16} 73.05
# LOL_{106,16} 73.05
# OL_{106,16} 73.05
# LOL_{107,16} 73.05
# OL_{107,16} 73.05
# LOL_{108,16} 73.05
# OL_{108,16} 73.05
# LOL_{109,16} 73.05
# OL_{109,16} 73.05
# LOL_{110,16} 73.05
# OL_{110,16} 73.05
# LOL_{111,16} 73.05
# OL_{111,16} 73.05
# LOL_{112,16} 73.05
# OL_{112,16} 73.05
# LOL_{113,16} 73.05
# OL_{113,16} 73.05
# LOL_{114,16} 73.05
# OL_{114,16} 73.05
# LOL_{115,16} 73.05
# OL_{115,16} 73.05
# LOL_{116,16} 73.05
# OL_{116,16} 73.05
# LOL_{117,16} 73.05
# OL_{117,16} 73.05
# LOL_{118,16} 73.05
# OL_{118,16} 73.05
# LOL_{119,16} 73.05
# OL_{119,16} 73.05
# LOL_{120,16} 73.05
# OL_{120,16} 73.05
# LOL_{121,16} 73.05
# OL_{121,16} 73.05
# LOL_{122,16} 73.05
# OL_{122,16} 73.05
# LOL_{123,16} 73.05
# OL_{123,16} 73.05
# LOL_{124,16} 73.05
# OL_{124,16} 73.05
# LOL_{101,17} 73.05
# OL_{101,17} 73.05
# LOL_{102,17} 73.05
# OL_{102,17} 73.05
# LOL_{103,17} 73.05
# OL_{103,17} 73.05
# LOL_{104,17} 73.05
# OL_{104,17} 73.05
# LOL_{105,17} 73.05
# OL_{105,17} 73.05
# LOL_{106,17} 73.05
# OL_{106,17} 73.05
# LOL_{107,17} 73.05
# OL_{107,17} 73.05
# LOL_{108,17} 73.05
# OL_{108,17} 73.05
# LOL_{109,17} 73.05
# OL_{109,17} 73.05
# LOL_{110,17} 73.05
# OL_{110,17} 73.05
# LOL_{111,17} 73.05
# OL_{111,17} 73.05
# LOL_{112,17} 73.05
# OL_{112,17} 73.05
# LOL_{113,17} 73.05
# OL_{113,17} 73.05
# LOL_{114,17} 73.05
# OL_{114,17} 73.05
# LOL_{115,17} 73.05
# OL_{115,17} 73.05
# LOL_{116,17} 73.05
# OL_{116,17} 73.05
# LOL_{117,17} 73.05
# OL_{117,17} 73.05
# LOL_{118,17} 73.05
# OL_{118,17} 73.05
# LOL_{119,17} 73.05
# OL_{119,17} 73.05
# LOL_{120,17} 73.05
# OL_{120,17} 73.05
# LOL_{121,17} 73.05
# OL_{121,17} 73.05
# LOL_{122,17} 73.05
# OL_{122,17} 73.05
# LOL_{123,17} 73.05
# OL_{123,17} 73.05
# LOL_{124,17} 73.05
# OL_{124,17} 73.05
# LOL_{101,18} 73.05
# OL_{101,18} 73.05
# LOL_{102,18} 73.05
# OL_{102,18} 73.05
# LOL_{103,18} 73.05
# OL_{103,18} 73.05
# LOL_{104,18} 73.05
# OL_{104,18} 73.05
# LOL_{105,18} 73.05
# OL_{105,18} 73.05
# LOL_{106,18} 73.05
# OL_{106,18} 73.05
# LOL_{107,18} 73.05
# OL_{107,18} 73.05
# LOL_{108,18} 73.05
# OL_{108,18} 73.05
# LOL_{109,18} 73.05
# OL_{109,18} 73.05
# LOL_{110,18} 73.05
# OL_{110,18} 73.05
# LOL_{111,18} 73.05
# OL_{111,18} 73.05
# LOL_{112,18} 73.05
# OL_{112,18} 73.05
# LOL_{113,18} 73.05
# OL_{113,18} 73.05
# LOL_{114,18} 73.05
# OL_{114,18} 73.05
# LOL_{115,18} 73.05
# OL_{115,18} 73.05
# LOL_{116,18} 73.05
# OL_{116,18} 73.05
# LOL_{117,18} 73.05
# OL_{117,18} 73.05
# LOL_{118,18} 73.05
# OL_{118,18} 73.05
# LOL_{119,18} 73.05
# OL_{119,18} 73.05
# LOL_{120,18} 73.05
# OL_{120,18} 73.05
# LOL_{121,18} 73.05
# OL_{121,18} 73.05
# LOL_{122,18} 73.05
# OL_{122,18} 73.05
# LOL_{123,18} 73.05
# OL_{123,18} 73.05
# LOL_{124,18} 73.05
# OL_{124,18} 73.05
# LOL_{101,19} 73.05
# OL_{101,19} 73.05
# LOL_{102,19} 73.05
# OL_{102,19} 73.05
# LOL_{103,19} 73.05
# OL_{103,19} 73.05
# LOL_{104,19} 73.05
# OL_{104,19} 73.05
# LOL_{105,19} 73.05
# OL_{105,19} 73.05
# LOL_{106,19} 73.05
# OL_{106,19} 73.05
# LOL_{107,19} 73.05
# OL_{107,19} 73.05
# LOL_{108,19} 73.05
# OL_{108,19} 73.05
# LOL_{109,19} 73.05
# OL_{109,19} 73.05
# LOL_{110,19} 73.05
# OL_{110,19} 73.05
# LOL_{111,19} 73.05
# OL_{111,19} 73.05
# LOL_{112,19} 73.05
# OL_{112,19} 73.05
# LOL_{113,19} 73.05
# OL_{113,19} 73.05
# LOL_{114,19} 73.05
# OL_{114,19} 73.05
# LOL_{115,19} 73.05
# OL_{115,19} 73.05
# LOL_{116,19} 73.05
# OL_{116,19} 73.05
# LOL_{117,19} 73.05
# OL_{117,19} 73.05
# LOL_{118,19} 73.05
# OL_{118,19} 73.05
# LOL_{119,19} 73.05
# OL_{119,19} 73.05
# LOL_{120,19} 73.05
# OL_{120,19} 73.05
# LOL_{121,19} 73.05
# OL_{121,19} 73.05
# LOL_{122,19} 73.05
# OL_{122,19} 73.05
# LOL_{123,19} 73.05
# OL_{123,19} 73.05
# LOL_{124,19} 73.05
# OL_{124,19} 73.05
# LOL_{101,20} 73.05
# OL_{101,20} 73.05
# LOL_{102,20} 73.05
# OL_{102,20} 73.05
# LOL_{103,20} 73.05
# OL_{103,20} 73.05
# LOL_{104,20} 73.05
# OL_{104,20} 73.05
# LOL_{105,20} 73.05
# OL_{105,20} 73.05
# LOL_{106,20} 73.05
# OL_{106,20} 73.05
# LOL_{107,20} 73.05
# OL_{107,20} 73.05
# LOL_{108,20} 73.05
# OL_{108,20} 73.05
# LOL_{109,20} 73.05
# OL_{109,20} 73.05
# LOL_{110,20} 73.05
# OL_{110,20} 73.05
# LOL_{111,20} 73.05
# OL_{111,20} 73.05
# LOL_{112,20} 73.05
# OL_{112,20} 73.05
# LOL_{113,20} 73.05
# OL_{113,20} 73.05
# LOL_{114,20} 73.05
# OL_{114,20} 73.05
# LOL_{115,20} 73.05
# OL_{115,20} 73.05
# LOL_{116,20} 73.05
# OL_{116,20} 73.05
# LOL_{117,20} 73.05
# OL_{117,20} 73.05
# LOL_{118,20} 73.05
# OL_{118,20} 73.05
# LOL_{119,20} 73.05
# OL_{119,20} 73.05
# LOL_{120,20} 73.05
# OL_{120,20} 73.05
# LOL_{121,20} 73.05
# OL_{121,20} 73.05
# LOL_{122,20} 73.05
# OL_{122,20} 73.05
# LOL_{123,20} 73.05
# OL_{123,20} 73.05
# LOL_{124,20} 73.05
# OL_{124,20} 73.05
# LOL_{101,21} 73.05
# OL_{101,21} 73.05
# LOL_{102,21} 73.05
# OL_{102,21} 73.05
# LOL_{103,21} 73.05
# OL_{103,21} 73.05
# LOL_{104,21} 73.05
# OL_{104,21} 73.05
# LOL_{105,21} 73.05
# OL_{105,21} 73.05
# LOL_{106,21} 73.05
# OL_{106,21} 73.05
# LOL_{107,21} 73.05
# OL_{107,21} 73.05
# LOL_{108,21} 73.05
# OL_{108,21} 73.05
# LOL_{109,21} 73.05
# OL_{109,21} 73.05
# LOL_{110,21} 73.05
# OL_{110,21} 73.05
# LOL_{111,21} 73.05
# OL_{111,21} 73.05
# LOL_{112,21} 73.05
# OL_{112,21} 73.05
# LOL_{113,21} 73.05
# OL_{113,21} 73.05
# LOL_{114,21} 73.05
# OL_{114,21} 73.05
# LOL_{115,21} 73.05
# OL_{115,21} 73.05
# LOL_{116,21} 73.05
# OL_{116,21} 73.05
# LOL_{117,21} 73.05
# OL_{117,21} 73.05
# LOL_{118,21} 73.05
# OL_{118,21} 73.05
# LOL_{119,21} 73.05
# OL_{119,21} 73.05
# LOL_{120,21} 73.05
# OL_{120,21} 73.05
# LOL_{121,21} 73.05
# OL_{121,21} 73.05
# LOL_{122,21} 73.05
# OL_{122,21} 73.05
# LOL_{123,21} 73.05
# OL_{123,21} 73.05
# LOL_{124,21} 73.05
# OL_{124,21} 73.05
# LOL_{101,22} 73.05
# OL_{101,22} 73.05
# LOL_{102,22} 73.05
# OL_{102,22} 73.05
# LOL_{103,22} 73.05
# OL_{103,22} 73.05
# LOL_{104,22} 73.05
# OL_{104,22} 73.05
# LOL_{105,22} 73.05
# OL_{105,22} 73.05
# LOL_{106,22} 73.05
# OL_{106,22} 73.05
# LOL_{107,22} 73.05
# OL_{107,22} 73.05
# LOL_{108,22} 73.05
# OL_{108,22} 73.05
# LOL_{109,22} 73.05
# OL_{109,22} 73.05
# LOL_{110,22} 73.05
# OL_{110,22} 73.05
# LOL_{111,22} 73.05
# OL_{111,22} 73.05
# LOL_{112,22} 73.05
# OL_{112,22} 73.05
# LOL_{113,22} 73.05
# OL_{113,22} 73.05
# LOL_{114,22} 73.05
# OL_{114,22} 73.05
# LOL_{115,22} 73.05
# OL_{115,22} 73.05
# LOL_{116,22} 73.05
# OL_{116,22} 73.05
# LOL_{117,22} 73.05
# OL_{117,22} 73.05
# LOL_{118,22} 73.05
# OL_{118,22} 73.05
# LOL_{119,22} 73.05
# OL_{119,22} 73.05
# LOL_{120,22} 73.05
# OL_{120,22} 73.05
# LOL_{121,22} 73.05
# OL_{121,22} 73.05
# LOL_{122,22} 73.05
# OL_{122,22} 73.05
# LOL_{123,22} 73.05
# OL_{123,22} 73.05
# LOL_{124,22} 73.05
# OL_{124,22} 73.05
# LOL_{101,23} 73.05
# OL_{101,23} 73.05
# LOL_{102,23} 73.05
# OL_{102,23} 73.05
# LOL_{103,23} 73.05
# OL_{103,23} 73.05
# LOL_{104,23} 73.05
# OL_{104,23} 73.05
# LOL_{105,23} 73.05
# OL_{105,23} 73.05
# LOL_{106,23} 73.05
# OL_{106,23} 73.05
# LOL_{107,23} 73.05
# OL_{107,23} 73.05
# LOL_{108,23} 73.05
# OL_{108,23} 73.05
# LOL_{109,23} 73.05
# OL_{109,23} 73.05
# LOL_{110,23} 73.05
# OL_{110,23} 73.05
# LOL_{111,23} 73.05
# OL_{111,23} 73.05
# LOL_{112,23} 73.05
# OL_{112,23} 73.05
# LOL_{113,23} 73.05
# OL_{113,23} 73.05
# LOL_{114,23} 73.05
# OL_{114,23} 73.05
# LOL_{115,23} 73.05
# OL_{115,23} 73.05
# LOL_{116,23} 73.05
# OL_{116,23} 73.05
# LOL_{117,23} 73.05
# OL_{117,23} 73.05
# LOL_{118,23} 73.05
# OL_{118,23} 73.05
# LOL_{119,23} 73.05
# OL_{119,23} 73.05
# LOL_{120,23} 73.05
# OL_{120,23} 73.05
# LOL_{121,23} 73.05
# OL_{121,23} 73.05
# LOL_{122,23} 73.05
# OL_{122,23} 73.05
# LOL_{123,23} 73.05
# OL_{123,23} 73.05
# LOL_{124,23} 73.05
# OL_{124,23} 73.05
# LOL_{101,24} 73.05
# OL_{101,24} 73.05
# LOL_{102,24} 73.05
# OL_{102,24} 73.05
# LOL_{103,24} 73.05
# OL_{103,24} 73.05
# LOL_{104,24} 73.05
# OL_{104,24} 73.05
# LOL_{105,24} 73.05
# OL_{105,24} 73.05
# LOL_{106,24} 73.05
# OL_{106,24} 73.05
# LOL_{107,24} 73.05
# OL_{107,24} 73.05
# LOL_{108,24} 73.05
# OL_{108,24} 73.05
# LOL_{109,24} 73.05
# OL_{109,24} 73.05
# LOL_{110,24} 73.05
# OL_{110,24} 73.05
# LOL_{111,24} 73.05
# OL_{111,24} 73.05
# LOL_{112,24} 73.05
# OL_{112,24} 73.05
# LOL_{113,24} 73.05
# OL_{113,24} 73.05
# LOL_{114,24} 73.05
# OL_{114,24} 73.05
# LOL_{115,24} 73.05
# OL_{115,24} 73.05
# LOL_{116,24} 73.05
# OL_{116,24} 73.05
# LOL_{117,24} 73.05
# OL_{117,24} 73.05
# LOL_{118,24} 73.05
# OL_{118,24} 73.05
# LOL_{119,24} 73.05
# OL_{119,24} 73.05
# LOL_{120,24} 73.05
# OL_{120,24} 73.05
# LOL_{121,24} 73.05
# OL_{121,24} 73.05
# LOL_{122,24} 73.05
# OL_{122,24} 73.05
# LOL_{123,24} 73.05
# OL_{123,24} 73.05
# LOL_{124,24} 73.05
# OL_{124,24} 73.05
# PR_{101} 50.0
# ER_{101} 2.0
# PR_{102} 50.0
# ER_{102} 2.0
# PR_{103} 50.0
# ER_{103} 2.0
# PR_{104} 50.0
# ER_{104} 2.0
# PR_{105} 50.0
# ER_{105} 2.0
# PR_{106} 50.0
# ER_{106} 2.0
# PR_{107} 50.0
# ER_{107} 2.0
# PR_{108} 50.0
# ER_{108} 2.0
# PR_{109} 50.0
# ER_{109} 2.0
# PR_{110} 50.0
# ER_{110} 2.0
# PR_{111} 50.0
# ER_{111} 2.0
# PR_{112} 50.0
# ER_{112} 2.0
# PR_{113} 50.0
# ER_{113} 2.0
# PR_{114} 50.0
# ER_{114} 2.0
# PR_{115} 50.0
# ER_{115} 2.0
# PR_{116} 50.0
# ER_{116} 2.0
# PR_{117} 50.0
# ER_{117} 2.0
# PR_{118} 50.0
# ER_{118} 2.0
# PR_{119} 50.0
# ER_{119} 2.0
# PR_{120} 50.0
# ER_{120} 2.0
# PR_{121} 50.0
# ER_{121} 2.0
# PR_{122} 50.0
# ER_{122} 2.0
# PR_{123} 50.0
# ER_{123} 2.0
# PR_{124} 50.0
# ER_{124} 2.0

# %%
0.036524999999999995*365.25
# Out:
# 13.340756249999998

# %% [markdown]
# Issue right now is the model would rather activate slack variables than buy storage. This is likely in part of the following:
#
# * Slack variable costs are too low
# * Operational storage costs are too high
# * thermal ramping is not a strong enough constraint.
#
# I would look into operational storage costs, first. Make sure they are accurate. From there, perhaps try doubling slack variables.

# %%
56.12*0.9021172688917519+ 0.3*0.7216938151134016
# Out:
# 50.84332927473913

# %%
get_stored_variable(ef, 101, 1, 1)
# Out:
# Est_{101_STORAGE_1,1}_1

# %%
modeltest = JuMP.read_from_file("./ef_12scen_test.mps")

JuMP.set_optimizer(modeltest, Gurobi.Optimizer)

optimize!(modeltest)
# Out:
# Academic license - for non-commercial use only - expires 2022-08-19
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 111817 rows, 70608 columns and 1439880 nonzeros
# Model fingerprint: 0x7c353256
# Coefficient statistics:
#   Matrix range     [2e-04, 5e+00]
#   Objective range  [5e-03, 6e+01]
#   Bounds range     [1e-01, 5e+00]
#   RHS range        [1e-03, 2e+02]
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Presolve removed 68916 rows and 21656 columns
# Presolve time: 0.82s
# Presolved: 42901 rows, 49780 columns, 1007088 nonzeros
#
# Ordering time: 0.08s
#
# Barrier statistics:
#  Dense cols : 48
#  AA' NZ     : 1.012e+06
#  Factor NZ  : 2.286e+06 (roughly 60 MBytes of memory)
#  Factor Ops : 1.743e+08 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.71178169e+06 -7.84623214e+05  9.56e+01 0.00e+00  8.68e+01     1s
#    1   1.52004592e+06 -4.23931529e+05  1.10e+02 7.62e-01  4.08e+01     1s
#    2   4.79506142e+05 -2.36924895e+05  3.05e+01 4.81e-07  1.23e+01     1s
#    3   4.55749482e+04 -7.80702676e+04  1.85e+00 5.91e-07  1.61e+00     2s
#    4   1.58424310e+04 -8.79299174e+03  2.84e-01 3.59e-07  2.98e-01     2s
#    5   6.35665687e+03 -8.35512819e+02  7.70e-02 5.24e-07  8.49e-02     2s
#    6   3.47502001e+03  2.15152081e+02  2.87e-02 3.50e-07  3.81e-02     2s
#    7   2.84147228e+03  6.15183019e+02  1.94e-02 4.73e-07  2.58e-02     2s
#    8   2.51580118e+03  1.01700932e+03  1.34e-02 3.16e-07  1.72e-02     2s
#    9   2.24569637e+03  1.27577911e+03  9.21e-03 6.67e-07  1.10e-02     2s
#   10   2.05070449e+03  1.32780649e+03  6.62e-03 3.88e-07  8.02e-03     2s
#     4031 Dual superbasic variables remain
#
#    30245 PPushes remaining with PInf 1.4057971e+01                21s
#        0 PPushes remaining with PInf 8.6521690e+00                23s
#
# Restart crossover...
#
#
#    30410 DPushes remaining with DInf 0.0000000e+00                23s
#        0 DPushes remaining with DInf 0.0000000e+00                24s
#
#     4029 Dual superbasic variables remain
#
#    30243 PPushes remaining with PInf 4.4801492e+01                24s
#    13497 PPushes remaining with PInf 3.5107556e+01                25s
#        0 PPushes remaining with PInf 1.6467494e+01                26s
#
#   Push phase complete: Pinf 1.6467494e+01, Dinf 2.9548202e+03     26s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    47425    1.5892158e+03   0.000000e+00   2.954820e+03     26s
#    50532    1.6154838e+03   0.000000e+00   0.000000e+00     28s
#
# Solved with barrier
# Solved in 50532 iterations and 27.85 seconds
# Optimal objective  1.615483802e+03
#
# User-callback calls 142535, time in user-callback 0.06 sec

# %%
vars = JuMP.all_variables(modeltest)

for bus in buses
    varPR = get_PR_variable(modeltest,bus,0)
    varER = get_ER_variable(modeltest,bus,0)
    
    println(varPR, " ", value(varPR))
    println(varER, " ", value(varER))
end
# Out:
# PR_{101}_0 0.0
# ER_{101}_0 0.0
# PR_{102}_0 0.0
# ER_{102}_0 0.0
# PR_{103}_0 0.0
# ER_{103}_0 0.0
# PR_{104}_0 0.0
# ER_{104}_0 0.0
# PR_{105}_0 0.0
# ER_{105}_0 0.0
# PR_{106}_0 0.0
# ER_{106}_0 0.0
# PR_{107}_0 0.0
# ER_{107}_0 0.0
# PR_{108}_0 0.0
# ER_{108}_0 0.0
# PR_{109}_0 0.0
# ER_{109}_0 0.0
# PR_{110}_0 0.0
# ER_{110}_0 0.0
# PR_{111}_0 0.0
# ER_{111}_0 0.0
# PR_{112}_0 0.0
# ER_{112}_0 0.0
# PR_{113}_0 0.0
# ER_{113}_0 0.0
# PR_{114}_0 0.0
# ER_{114}_0 0.0
# PR_{115}_0 0.0
# ER_{115}_0 0.0
# PR_{116}_0 0.0
# ER_{116}_0 0.0
# PR_{117}_0 0.29836541821226453
# ER_{117}_0 0.23869233456981162
# PR_{118}_0 0.0
# ER_{118}_0 0.0
# PR_{119}_0 0.0
# ER_{119}_0 0.0
# PR_{120}_0 0.0
# ER_{120}_0 0.0
# PR_{121}_0 0.0
# ER_{121}_0 0.0
# PR_{122}_0 0.4866000204996435
# ER_{122}_0 0.3892800163997148
# PR_{123}_0 0.0
# ER_{123}_0 0.0
# PR_{124}_0 0.0
# ER_{124}_0 0.0

# %%
count = 0
for (var, coeff) in JuMP.objective_function(modeltest).terms
    count += 1
    if count > 1000 && count < 2000
    println(var, " ", coeff)
    end
end
# Out:
# Pdis_{117_STORAGE_1,16}_1 0.004565624999999999
# Pdis_{118_STORAGE_1,16}_1 0.004565624999999999
# Pdis_{119_STORAGE_1,16}_1 0.004565624999999999
# Pdis_{120_STORAGE_1,16}_1 0.004565624999999999
# Pdis_{121_STORAGE_1,16}_1 0.004565624999999999
# Pdis_{122_STORAGE_1,16}_1 0.004565624999999999
# Pdis_{123_STORAGE_1,16}_1 0.004565624999999999
# Pdis_{124_STORAGE_1,16}_1 0.004565624999999999
# Pdis_{101_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{102_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{103_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{104_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{105_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{106_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{107_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{108_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{109_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{110_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{111_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{112_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{113_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{114_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{115_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{116_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{117_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{118_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{119_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{120_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{121_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{122_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{123_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{124_STORAGE_1,17}_1 0.004565624999999999
# Pdis_{101_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{102_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{103_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{104_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{105_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{106_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{107_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{108_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{109_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{110_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{111_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{112_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{113_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{114_STORAGE_1,18}_1 0.004565624999999999
# Pdis_{115_STORAGE_1,18}_1 0.004565624999999999
# Pdis_
# LOL_{106,24}_1 24.349999999999998
# LOL_{107,24}_1 24.349999999999998
# LOL_{108,24}_1 24.349999999999998
# LOL_{109,24}_1 24.349999999999998
# LOL_{110,24}_1 24.349999999999998
# LOL_{111,24}_1 24.349999999999998
# LOL_{112,24}_1 24.349999999999998
# LOL_{113,24}_1 24.349999999999998
# LOL_{114,24}_1 24.349999999999998
# LOL_{115,24}_1 24.349999999999998
# LOL_{116,24}_1 24.349999999999998
# LOL_{117,24}_1 24.349999999999998
# LOL_{118,24}_1 24.349999999999998
# LOL_{119,24}_1 24.349999999999998
# LOL_{120,24}_1 24.349999999999998
# LOL_{121,24}_1 24.349999999999998
# LOL_{122,24}_1 24.349999999999998
# LOL_{123,24}_1 24.349999999999998
# LOL_{124,24}_1 24.349999999999998
# OL_{101,1}_1 6.0874999999999995
# OL_{102,1}_1 6.0874999999999995
# OL_{103,1}_1 6.0874999999999995
# OL_{104,1}_1 6.0874999999999995
# OL_{105,1}_1 6.0874999999999995
# OL_{106,1}_1 6.0874999999999995
# OL_{107,1}_1 6.0874999999999995
# OL_{108,1}_1 6.0874999999999995
# OL_{109,1}_1 6.0874999999999995
# OL_{110,1}_1 6.0874999999999995
# OL_{111,1}_1 6.0874999999999995
# OL_{112,1}_1 6.0874999999999995
# OL_{113,1}_1 6.0874999999999995
# OL_{114,1}_1 6.0874999999999995
# OL_{115,1}_1 6.0874999999999995
# OL_{116,1}_1 6.0874999999999995
# OL_{117,1}_1 6.0874999999999995
# OL_{118,1}_1 6.0874999999999995
# OL_{119,1}_1 6.0874999999999995
# OL_{120,1}_1 6.0874999999999995
# OL_{121,1}_1 6.0874999999999995
# OL_{122,1}_1 6.0874999999999995
# OL_{123,1}_1 6.0874999999999995
# OL_{124,1}_1 6.0874999999999995
# OL_{101,2}_1 6.0874999999999995
# OL_{102,2}_1 6.0874999999999995
# OL_{103,2}_1 6.0874999999999995
# OL_{104,2}_1 6.0874999999999995
# OL_{105,2}_1 6.0874999999999995
# OL_{106,2}_1 6.0874999999999995
# OL_{107,2}_1 6.0874999999999995
# OL_{108,2}_1 6.0874999999999995
# OL_{109,2}_1 6.0874999999999995
# OL_{110,2}_1 6.0874999999999995
# OL_{111,2}_1 6.0874999999999995
# OL_{112,2}_1 6.0874999999999995
# OL_{113,2}_1 6.0874999999999995
# OL_{114,2}_1 6.0874999999999995
# OL_{115,2}_1 6.0874999999999995
# OL_{116,2}_1 6.0874999999999995
# OL_{117,2}_1 6.0874999999999995
# OL_{118,2}_1 6.0874999999999995
# OL_{119,2}_1 6.0874999999999995
# OL_{120,2}_1 6.0874999999999995
# OL_{121,2}_1 6.0874999999999995
# OL_{122,2}_1 6.0874999999999995
# OL_{123,2}_1 6.0874999999999995
# OL_{124,2}_1 6.0874999999999995
# OL_{101,3}_1 6.0874999999999995
# OL_{102,3}_1 6.0874999999999995
# OL_{103,3}_1 6.0874999999999995
# OL_{104,3}_1 6.0874999999999995
# OL_{105,3}_1 6.0874999999999995
# OL_{106,3}_1 6.0874999999999995
# OL_{107,3}_1 6.0874999999999995
# OL_{108,3}_1 6.0874999999999995
# OL_{109,3}_1 6.0874999999999995
# OL_{110,3}_1 6.0874999999999995
# OL_{111,3}_1 6.0874999999999995
# OL_{112,3}_1 6.0874999999999995
# OL_{113,3}_1 6.0874999999999995
# OL_{114,3}_1 6.0874999999999995
# OL_{115,3}_1 6.0874999999999995
# OL_{116,3}_1 6.0874999999999995
# OL_{117,3}_1 6.0874999999999995
# OL_{118,3}_1 6.0874999999999995
# OL_{119,3}_1 6.0874999999999995
# OL_{120,3}_1 6.0874999999999995
# OL_{121,3}_1 6.0874999999999995
# OL_{122,3}_1 6.0874999999999995
# OL_{123,3}_1 6.0874999999999995
# OL_{124,3}_1 6.0874999999999995
# OL_{101,4}_1 6.0874999999999995
# OL_{102,4}_1 6.0874999999999995
# OL_{103,4}_1 6.0874999999999995
# OL_{104,4}_1 6.0874999999999995
# OL_{105,4}_1 6.0874999999999995
# OL_{106,4}_1 6.0874999999999995
# OL_{107,4}_1 6.0874999999999995
# OL_{108,4}_1 6.0874999999999995
# OL_{109,4}_1 6.0874999999999995
# OL_{110,4}_1 6.0874999999999995
# OL_{111,4}_1 6.0874999999999995
# OL_{112,4}_1 6.0874999999999995
# OL_{113,4}_1 6.0874999999999995
# OL_{114,4}_1 6.0874999999999995
# OL_{115,4}_1 6.0874999999999995
# OL_{116,4}_1 6.0874999999999995
# OL_{117,4}_1 6.0874999999999995
# OL_{118,4}_1 6.0874999999999995
# OL_{119,4}_1 6.0874999999999995
# OL_{120,4}_1 6.0874999999999995
# OL_{121,4}_1 6.0874999999999995
# OL_{122,4}_1 6.0874999999999995
# OL_{123,4}_1 6.0874999999999995
# OL_{124,4}_1 6.0874999999999995
# OL_{101,5}_1 6.0874999999999995
# OL_{102,5}_1 6.0874999999999995
# OL_{103,5}_1 6.0874999999999995
# OL_{104,5}_1 6.0874999999999995
# OL_{105,5}_1 6.0874999999999995
# OL_{106,5}_1 6.0874999999999995
# OL_{107,5}_1 6.0874999999999995
# OL_{108,5}_1 6.0874999999999995
# OL_{109,5}_1 6.0874999999999995
# OL_{110,5}_1 6.0874999999999995
# OL_{111,5}_1 6.0874999999999995
# OL_{112,5}_1 6.0874999999999995
# OL_{113,5}_1 6.0874999999999995
# OL_{114,5}_1 6.0874999999999995
# OL_{115,5}_1 6.0874999999999995
# OL_{116,5}_1 6.0874999999999995
# OL_{117,5}_1 6.0874999999999995
# OL_{118,5}_1 6.0874999999999995
# OL_{119,5}_1 6.0874999999999995
# OL_{120,5}_1 6.0874999999999995
# OL_{121,5}_1 6.0874999999999995
# OL_{122,5}_1 6.0874999999999995
# OL_{123,5}_1 6.0874999999999995
# OL_{124,5}_1 6.0874999999999995
# OL_{101,6}_1 6.0874999999999995
# OL_{102,6}_1 6.0874999999999995
# OL_{103,6}_1 6.0874999999999995
# OL_{104,6}_1 6.0874999999999995
# OL_{105,6}_1 6.0874999999999995
# OL_{106,6}_1 6.0874999999999995
# OL_{107,6}_1 6.0874999999999995
# OL_{108,6}_1 6.0874999999999995
# OL_{109,6}_1 6.0874999999999995
# OL_{110,6}_1 6.0874999999999995
# OL_{111,6}_1 6.0874999999999995
# OL_{112,6}_1 6.0874999999999995
# OL_{113,6}_1 6.0874999999999995
# OL_{114,6}_1 6.0874999999999995
# OL_{115,6}_1 6.0874999999999995
# OL_{116,6}_1 6.0874999999999995
# OL_{117,6}_1 6.0874999999999995
# OL_{118,6}_1 6.0874999999999995
# OL_{119,6}_1 6.0874999999999995
# OL_{120,6}_1 6.0874999999999995
# OL_{121,6}_1 6.0874999999999995
# OL_{122,6}_1 6.0874999999999995
# OL_{123,6}_1 6.0874999999999995
# OL_{124,6}_1 6.0874999999999995
# OL_{101,7}_1 6.0874999999999995
# OL_{102,7}_1 6.0874999999999995
# OL_{103,7}_1 6.0874999999999995
# OL_{104,7}_1 6.0874999999999995
# OL_{105,7}_1 6.0874999999999995
# OL_{106,7}_1 6.0874999999999995
# OL_{107,7}_1 6.0874999999999995
# OL_{108,7}_1 6.0874999999999995
# OL_{109,7}_1 6.0874999999999995
# OL_{110,7}_1 6.0874999999999995
# OL_{111,7}_1 6.0874999999999995
# OL_{112,7}_1 6.0874999999999995
# OL_{113,7}_1 6.0874999999999995
# OL_{114,7}_1 6.0874999999999995
# OL_{115,7}_1 6.0874999999999995
# OL_{116,7}_1 6.0874999999999995
# OL_{117,7}_1 6.0874999999999995
# OL_{118,7}_1 6.0874999999999995
# OL_{119,7}_1 6.0874999999999995
# OL_{120,7}_1 6.0874999999999995
# OL_{121,7}_1 6.0874999999999995
# OL_{122,7}_1 6.0874999999999995
# OL_{123,7}_1 6.0874999999999995
# OL_{124,7}_1 6.0874999999999995
# OL_{101,8}_1 6.0874999999999995
# OL_{102,8}_1 6.0874999999999995
# OL_{103,8}_1 6.0874999999999995
# OL_{104,8}_1 6.0874999999999995
# OL_{105,8}_1 6.0874999999999995
# OL_{106,8}_1 6.0874999999999995
# OL_{107,8}_1 6.0874999999999995
# OL_{108,8}_1 6.0874999999999995
# OL_{109,8}_1 6.0874999999999995
# OL_{110,8}_1 6.0874999999999995
# OL_{111,8}_1 6.0874999999999995
# OL_{112,8}_1 6.0874999999999995
# OL_{113,8}_1 6.0874999999999995
# OL_{114,8}_1 6.0874999999999995
# OL_{115,8}_1 6.0874999999999995
# OL_{116,8}_1 6.0874999999999995
# OL_{117,8}_1 6.0874999999999995
# OL_{118,8}_1 6.0874999999999995
# OL_{119,8}_1 6.0874999999999995
# OL_{120,8}_1 6.0874999999999995
# OL_{121,8}_1 6.0874999999999995
# OL_{122,8}_1 6.0874999999999995
# OL_{123,8}_1 6.0874999999999995
# OL_{124,8}_1 6.0874999999999995
# OL_{101,9}_1 6.0874999999999995
# OL_{102,9}_1 6.0874999999999995
# OL_{103,9}_1 6.0874999999999995
# OL_{104,9}_1 6.0874999999999995
# OL_{105,9}_1 6.0874999999999995
# OL_{106,9}_1 6.0874999999999995
# OL_{107,9}_1 6.0874999999999995
# OL_{108,9}_1 6.0874999999999995
# OL_{109,9}_1 6.0874999999999995
# OL_{110,9}_1 6.0874999999999995
# OL_{111,9}_1 6.0874999999999995
# OL_{112,9}_1 6.0874999999999995
# OL_{113,9}_1 6.0874999999999995
# OL_{114,9}_1 6.0874999999999995
# OL_{115,9}_1 6.0874999999999995
# OL_{116,9}_1 6.0874999999999995
# OL_{117,9}_1 6.0874999999999995
# OL_{118,9}_1 6.0874999999999995
# OL_{119,9}_1 6.0874999999999995
# OL_{120,9}_1 6.0874999999999995
# OL_{121,9}_1 6.0874999999999995
# OL_{122,9}_1 6.0874999999999995
# OL_{123,9}_1 6.0874999999999995
# OL_{124,9}_1 6.0874999999999995
# OL_{101,10}_1 6.0874999999999995
# OL_{102,10}_1 6.0874999999999995
# OL_{103,10}_1 6.0874999999999995
# OL_{104,10}_1 6.0874999999999995
# OL_{105,10}_1 6.0874999999999995
# OL_{106,10}_1 6.0874999999999995
# OL_{107,10}_1 6.0874999999999995

# %%
get_ER_ub(modeltest,101,0)
# Out:
# MethodError: no method matching constraint_by_name(::Model, ::String, ::Int64)
# Closest candidates are:
#   constraint_by_name(::Model, ::String) at C:\Users\micha\.julia\packages\JuMP\Xrr7O\src\constraints.jl:202
#   constraint_by_name(::Model, ::String, ::Type{var"#s142"} where var"#s142"<:MathOptInterface.AbstractFunction, ::Type{var"#s141"} where var"#s141"<:MathOptInterface.AbstractSet) at C:\Users\micha\.julia\packages\JuMP\Xrr7O\src\constraints.jl:211
#   constraint_by_name(::Model, ::String, ::Type{var"#s142"} where var"#s142"<:Union{Vector{ScalarType}, ScalarType}, ::Type) where ScalarType<:AbstractJuMPScalar at C:\Users\micha\.julia\packages\JuMP\Xrr7O\src\constraints.jl:224
#
# Stacktrace:
#  [1] get_ER_ub(model::Model, bus::Int64, scenario::Int64)
#    @ Main C:\Users\micha\repos\FinalProject\get_functions.jl:202
#  [2] top-level scope
#    @ In[39]:1
#  [3] eval
#    @ .\boot.jl:360 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1094

# %%
for bus in buses
    if bus == 117
        JuMP.fix(get_PR_variable(modeltest,bus,0),.6923494966775686)
        JuMP.fix(get_ER_variable(modeltest,bus,0),.5538795973420549)
    elseif bus == 117
        JuMP.fix(get_PR_variable(modeltest,bus,0),0.09261709522879528)
        JuMP.fix(get_ER_variable(modeltest,bus,0),0.07409367618303624)
    else
        JuMP.fix(get_PR_variable(modeltest,bus,0),0.0)
        JuMP.fix(get_ER_variable(modeltest,bus,0),0.0)
    end
end

# %%
optimize!(modeltest)
# Out:
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 111817 rows, 70608 columns and 1439880 nonzeros
# Coefficient statistics:
#   Matrix range     [2e-04, 5e+00]
#   Objective range  [5e-03, 6e+01]
#   Bounds range     [1e-01, 5e+00]
#   RHS range        [1e-03, 2e+02]
#        0    1.6154838e+03   1.585051e+00   0.000000e+00      0s
#      180    1.6170066e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 180 iterations and 0.24 seconds
# Optimal objective  1.617006551e+03
#
# User-callback calls 142732, time in user-callback 0.06 sec

# %%
(1.617006551e+03-1.615483802e+03)/1.615483802e+03*100
# Out:
# 0.09425962662793547
